# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("people_tracked.csv")

# %%
coordinates=  np.array(df)

# %%
modulus = np.sqrt(np.power(coordinates[:, 0], 2) + np.power(coordinates[:, 1], 2))

# %%
plt.plot(modulus)

# %%
plt.scatter(coordinates[:,0], coordinates[:, 1])

# %%
theta = np.rad2deg(
            np.arctan2(coordinates[:, 1], coordinates[:, 0]))

# %%
plt.plot(theta)

# %%
from proxemics_analizer.actor_position.ActorPositionCounter import ActorPositionCounter
from proxemics_analizer.actor_position.StandardActorPositionComputer import StandardActorPositionComputer

# %%
counter = ActorPositionCounter(StandardActorPositionComputer())

# %%
positions = []
for a in theta:
    positions.append(counter.update(a))
# Out:
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# Returning LEFT
# ...

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(positions)
ax[1].plot(theta)
