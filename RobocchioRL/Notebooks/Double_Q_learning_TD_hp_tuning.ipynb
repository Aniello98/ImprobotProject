# %%
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Tuple
import copy
import numpy as np
import random, json, csv, os

# %%
train = True
model_name = "Double_Q_Learning_tuning_alp_"

# %%
ACTIONS = [ "none",
            "attack",
            "scolding",
            "intimidate",
            "grudge",
            "sharing_happiness",
            "happy_person",
            "satisfaction",
            "sharing_fear",
            "running_away",
            "sharing_sadness",
            "disappointment",
            "surprise",
            "disbelief",
            "astonishment"
            ]

            
            
EMOTIONS = ["none",
            "fear",
            "joy",
            "surprise",
            "sadness",
            "anger"
            ]

EMOTION_PER_ACTION = { "none": "none",
            "attack" : "anger",
            "scolding": "anger",
            "intimidate": "anger",
            "grudge": "anger",
            "sharing_happiness": "joy",
            "happy_person": "joy",
            "satisfaction": "joy",
            "sharing_fear": "fear",
            "running_away": "fear",
            "sharing_sadness": "sadness",
            "disappointment": "sadness",
            "surprise": "surprise",
            "disbelief": "surprise",
            "astonishment": "surprise"
}

# %%
SCENIC_ACTION_SIZE = len(ACTIONS)
EMOTIONAL_REACTION_SIZE = len(EMOTIONS)

MAXIMUM_SKETCH_LENGTH = 15

# %%
# returns the code number of an action given by name
def parse_action(action):
    return ACTIONS.index(action)

#returns the action associated to a code
def unparse_action(code):
    return ACTIONS[code]

# returns the code number of an action given by name
def parse_emotion(action):
    return EMOTIONS.index(action)

#returns the action associated to a code
def unparse_emotion(code):
    return EMOTIONS[code]

def convert_action_into_emo(action):
    return EMOTION_PER_ACTION[action]

# %%
class ImprobotEnv(Env):

    def __init__(self, actor_space, robot_space, sketch_lenght, env_matrix, P0):

        self.action_space = Discrete(len(robot_space))
        # environment conditions space
        self.observation_space = Tuple((Discrete(len(robot_space)), Discrete(len(actor_space)))) # (robot reaction, actor action)
        self.state = () # (last robot reaction, last actor action)
        self.initial_action_P = P0
        self.sketch_length = sketch_lenght
        self.counter = 0
        self.P = env_matrix # {action: [probability, actor_action, reward]}
        self.q_table_1 = np.zeros([self.observation_space[0].n, self.observation_space[1].n, self.action_space.n])
        self.q_table_2 = np.zeros([self.observation_space[0].n, self.observation_space[1].n, self.action_space.n])
    
    def render(self):
        print(f"Last actor scenic action: {self.state[1]}")
        print(f"Last robot reaction: {self.state[0]}")

    def step(self, action):
        possible_next_states = self.P[action]
        probabilities = []

        for elem in possible_next_states:
            probabilities.append(elem[0])

        #print(probabilities)
        #print(possible_next_states)
        new_observation_idx = np.random.choice(len(possible_next_states), p=probabilities)
        
        new_observation = possible_next_states[new_observation_idx]
        # update state
        new_reaction = action
        new_actor_action = new_observation[1]
        self.state = tuple([new_reaction, new_actor_action])
        reward = new_observation[2]

        #self.counter += 1

        if self.counter == self.sketch_length:
            done = True
        else:
            done = False

        return self.state, reward, done

    def reset(self):
        actor_action = np.random.choice(SCENIC_ACTION_SIZE,p=self.initial_action_P)
        #print(f"initial action: {actor_action}")
        self.state = (0, actor_action) # (none, none)
        self.counter = 0
        return self.state

# %%
# initial action probability distribution
equal_prob = 1/(SCENIC_ACTION_SIZE-1)
P0 = np.zeros(15)
P0[1:] = np.full(14, equal_prob)

# %% [markdown]
# # DOUBLE-Q-Learning

# %%
def double_q_learning_train(alpha, gamma, epsilon, TD_step, min_q_diff, env):
    # mask in order to non choose action none during the training
    mask = np.ones(env.observation_space[0].n, dtype=np.int8)
    mask[0] = 0

    epochs_number = 100000

    for i in range(1, epochs_number):
        q_old_1 = copy.deepcopy(env.q_table_1)
        q_old_2 = copy.deepcopy(env.q_table_2)
        state = env.reset()

        epochs, reward = 0, 0
        done = False
        
        epsilon = -0.9/50000 * i + 1 if i < 50000 else 0.1

        while not done:

            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample(mask=mask) # Explore action space
                #print(f"random action: {action}")
            else:
                # choose action using q1+q2 value
                action_values = env.q_table_1[state[0]][state[1]][1:] + env.q_table_2[state[0]][state[1]][1:]
                action = np.argmax(action_values) + 1 # Exploit learned values
                #print(f"argmax action: {action}")

            initial_action = action
            states = []
            G = []
            rewds = []
            gamma_arr = []
            
            if random.uniform(0,1) < 0.5:
                old_value = env.q_table_1[state[0]][state[1]][action]
                table_to_update = 1
            else:
                old_value = env.q_table_2[state[0]][state[1]][action]
                table_to_update = 2

            for j in range(TD_step+1):
                if env.counter + j < env.sketch_length:
                    next_state, reward, done = env.step(action)
                    states.append(next_state)
                    rewds.append(reward)
                    gamma_arr.append(gamma**(j))
                    # update q1 or q2 table with probbility 0.5
                    if random.uniform(0, 1) < epsilon:
                        action = env.action_space.sample(mask=mask) # Explore action space
                        #print(f"random action: {action}")
                    else:
                        action_values = env.q_table_1[next_state[0]][next_state[1]][1:] + env.q_table_2[next_state[0]][next_state[1]][1:]
                        action = np.argmax(action_values) + 1 # Exploit learned values
                        #print(f"argmax action: {action}")
                else:
                    break
            
            if env.counter + TD_step < env.sketch_length:
                # update q1 or q2 table with probbility 0.5
                if table_to_update == 1:
                    next_value = env.q_table_2[next_state[0]][next_state[1]][np.argmax(env.q_table_1[next_state[0]][next_state[1]][1:]) + 1]
                    rewds.append(next_value)
                    gamma_arr.append(gamma ** (TD_step+1))
                    #G = np.multiply(rewds,gamma)
            

                else:
                    next_value = env.q_table_1[next_state[0]][next_state[1]][np.argmax(env.q_table_2[next_state[0]][next_state[1]][1:]) + 1]
                    rewds.append(next_value)
                    gamma_arr.append(gamma ** (TD_step+1))
                    #G = np.multiply(rewds,gamma)
            
                    #new_value = (1 - alpha) * old_value + np.sum(alpha * np.array(G))
                    #env.q_table_2[state[0]][state[1]][initial_action] = new_value
            
            G = np.multiply(rewds,gamma)

            if table_to_update == 1:
                new_value = (1 - alpha) * old_value + np.sum(alpha * np.array(G))
                env.q_table_1[state[0]][state[1]][initial_action] = new_value
            else:
                new_value = (1 - alpha) * old_value + np.sum(alpha * np.array(G))
                env.q_table_2[state[0]][state[1]][initial_action] = new_value  
            
            state = states[0]
            
            #state = next_state
            epochs += 1

            env.counter += 1

            if env.counter == env.sketch_length:
                done = True
            else:
                done = False

            #print(f"Episode: {i}")
            #print(f"Epoch: {epochs}")
            #print(f"actual_state: {env.state}")
            #print(f"action choosen: {action}")
            #print(f"next_state: {next_state}")
            #print(f"q_value updated: {env.q_table[state[0]][state[1]][action]}")

        if i % 100 == 0:
            print(f"Episode: {i}")
            print(f"action choosen: {action}")
            print(f"next_state: {next_state}")
            print(f"q_value updated: {env.q_table_1[state[0]][state[1]][action]}")

# %%
def policy_eval(env):
    total_epochs = 0
    total_rewards = 0
    episodes = 100

    for _ in range(episodes):
        state = env.reset()
        epochs, reward = 0, 0
        
        done = False
        
        while not done:
            action_values = env.q_table_1[state[0]][state[1]][1:] + env.q_table_2[state[0]][state[1]][1:]
            action = np.argmax(action_values) + 1 # Exploit learned values
            state, reward, _ = env.step(action)

            total_rewards += reward

            env.counter += 1

            if env.counter == env.sketch_length:
                done = True
            else:
                done = False

            epochs += 1

        total_epochs += epochs

    print(f"Results after {episodes} episodes:")
    print(f"Average timesteps per episode: {total_epochs / episodes}")
    print(f"Average rewards per episode: {total_rewards / episodes}")
    return total_rewards / episodes

# %%
def save_q_table(env,table_name, dir_name):
    reshaped_Q_1 = env.q_table_1.reshape((env.q_table_1.shape[0]*env.q_table_1.shape[1]),env.q_table_1.shape[2])
    reshaped_Q_2 = env.q_table_2.reshape((env.q_table_2.shape[0]*env.q_table_2.shape[1]),env.q_table_2.shape[2])
    reshaped_Q = np.add(reshaped_Q_1,reshaped_Q_2)
    header = ["S(robot reaction, actor action)", "none", "attack", "scolding", "intimidate", "grudge", "sharing_happiness",
          "happy_person", "satisfaction", "sharing_fear", "running_away", "sharing_sadness", "disappointment",
          "surprise", "disbelief", "astonishment"] if env.observation_space[0].n == 15 else ["S(robot reaction, actor action)", "none", "fear", "joy", "surprise", "sadness", "anger"]
    reaction_unparser = unparse_action if env.observation_space[0].n == 15 else unparse_emotion
    
    data = []
    
    for i in range(reshaped_Q.shape[0]):
        if int(i/env.observation_space[1].n) == 0:
            reaction = reaction_unparser(0)
            row = [(reaction,unparse_action(i))]
        else:
            reaction = int(i/env.observation_space[1].n)
            #print(f"here is the reaction: {reaction}")
            #print(f"here is the i: {i}")
            reaction = reaction_unparser(reaction)
            row = [(reaction, unparse_action((i%env.observation_space[1].n)))]
        row.extend(reshaped_Q[i])
        data.append(row)

    # Scrittura del file CSV
    if not os.path.exists('trials/' + dir_name):
        os.makedirs('trials/' + dir_name)

    with open('trials/' + dir_name + '/' + table_name + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(data)

# %% [markdown]
# # Action-per-Action learning Test

# %% [markdown]
# ### Load P action per action matrix

# %%
with open('P_action_per_action.json') as f:
    P_aa = json.load(f)

print(P_aa)

# convert keys into numbers
new_P = {}
for k in P_aa.keys():
    new_P[int(k)]=P_aa[k]

P_aa = new_P
print(P_aa)
# Out:
# {'1': [[0.125, 3, 2], [0.125, 5, 0], [0.125, 6, -4], [0.125, 7, 0], [0.125, 8, 4], [0.25, 10, -1], [0.125, 11, 3]], '2': [[0.14285714285714285, 1, 1], [0.14285714285714285, 2, 4], [0.14285714285714285, 8, 0], [0.2857142857142857, 10, 13], [0.14285714285714285, 11, 4], [0.14285714285714285, 14, 2]], '3': [[0.25, 3, 5], [0.08333333333333333, 4, 0], [0.08333333333333333, 5, 12], [0.16666666666666666, 6, 6], [0.08333333333333333, 7, 0], [0.08333333333333333, 8, 2], [0.25, 10, 9]], '4': [[0.125, 3, 0], [0.125, 8, 1], [0.5, 10, 2], [0.25, 11, 1]], '5': [[0.1, 2, 1], [0.1, 5, 1], [0.2, 6, 8], [0.2, 8, 11], [0.2, 10, 15], [0.1, 11, 2], [0.1, 13, 6]], '6': [[0.08333333333333333, 2, 1], [0.08333333333333333, 3, -2], [0.08333333333333333, 5, 0], [0.3333333333333333, 6, 26], [0.08333333333333333, 8, 0], [0.16666666666666666, 11, -2], [0.08333333333333333, 12, -1], [0.08333333333333333, 14, 3]], '7': [[0.25, 3, 6], [0.125, 7, 0], [0.375, 10, 4], [0.125, 11, 3], [0.125, 12, -1]], '8': [[0.2, 3, 6], [0.1, 5, 4], [0.1, 7, 0], [0.4, 8, 7], [0.2, 10, 5]], '9': [[0.3333333333333333, 6, 4], [0.6666666666666666, 10, -3]], '10': [[0.08333333333333333, 2, 3], [0.16666666666666666, 3, 1], [0.08333333333333333, 4, 1], [0.08333333333333333, 6, 3], [0.16666666666666666, 8, -3], [0.16666666666666666, 10, 1], [0.16666666666666666, 12, -2], [0.08333333333333333, 13, 2]], '11': [[0.08333333333333333, 4, -1], [0.08333333333333333, 5, -1], [0.25, 6, -3], [0.08333333333333333, 8, 1], [0.3333333333333333, 10, -6], [0.08333333333333333, 11, -1], [0.08333333333333333, 13, 0]], '12': [[0.05263157894736842, 4, 3], [0.05263157894736842, 5, 0], [0.2631578947368421, 6, 9], [0.05263157894736842, 7, 1], [0.10526315789473684, 8, 3], [0.2631578947368421, 10, -1], [0.10526315789473684, 11, -2], [0.05263157894736842, 12, 4], [0.05263157894736842, 14, 3]], '13': [[0.1111111111111111, 1, -1], [0.1111111111111111, 2, 0], [0.1111111111111111, 5, 0], [0.1111111111111111, 6, 0], [0.3333333333333333, 10, 5], [0.2222222222222222, 11, 8]], '14': [[0.125, 2, 6], [0.16666666666666666, 3, 2], [0.041666666666666664, 4, 1], [0.08333333333333333, 5, 1], [0.125, 6, -1], [0.125, 7, 5], [0.16666666666666666, 10, 2], [0.08333333333333333, 11, 0], [0.08333333333333333, 14, 0]]}
# {1: [[0.125, 3, 2], [0.125, 5, 0], [0.125, 6, -4], [0.125, 7, 0], [0.125, 8, 4], [0.25, 10, -1], [0.125, 11, 3]], 2: [[0.14285714285714285, 1, 1], [0.14285714285714285, 2, 4], [0.14285714285714285, 8, 0], [0.2857142857142857, 10, 13], [0.14285714285714285, 11, 4], [0.14285714285714285, 14, 2]], 3: [[0.25, 3, 5], [0.08333333333333333, 4, 0], [0.08333333333333333, 5, 12], [0.16666666666666666, 6, 6], [0.08333333333333333, 7, 0], [0.08333333333333333, 8, 2], [0.25, 10, 9]], 4: [[0.125, 3, 0], [0.125, 8, 1], [0.5, 10, 2], [0.25, 11, 1]], 5: [[0.1, 2, 1], [0.1, 5, 1], [0.2, 6, 8], [0.2, 8, 11], [0.2, 10, 15], [0.1, 11, 2], [0.1, 13, 6]], 6: [[0.08333333333333333, 2, 1], [0.08333333333333333, 3, -2], [0.08333333333333333, 5, 0], [0.3333333333333333, 6, 26], [0.08333333333333333, 8, 0], [0.16666666666666666, 11, -2], [0.08333333333333333, 12, -1], [0.08333333333333333, 14, 3]], 7: [[0.25, 3, 6], [0.125, 7, 0], [0.375, 10, 4], [0.125, 11, 3], [0.125, 12, -1]], 8: [[0.2, 3, 6], [0.1, 5, 4], [0.1, 7, 0], [0.4, 8, 7], [0.2, 10, 5]], 9: [[0.3333333333333333, 6, 4], [0.6666666666666666, 10, -3]], 10: [[0.08333333333333333, 2, 3], [0.16666666666666666, 3, 1], [0.08333333333333333, 4, 1], [0.08333333333333333, 6, 3], [0.16666666666666666, 8, -3], [0.16666666666666666, 10, 1], [0.16666666666666666, 12, -2], [0.08333333333333333, 13, 2]], 11: [[0.08333333333333333, 4, -1], [0.08333333333333333, 5, -1], [0.25, 6, -3], [0.08333333333333333, 8, 1], [0.3333333333333333, 10, -6], [0.08333333333333333, 11, -1], [0.08333333333333333, 13, 0]], 12: [[0.05263157894736842, 4, 3], [0.05263157894736842, 5, 0], [0.2631578947368421, 6, 9], [0.05263157894736842, 7, 1], [0.10526315789473684, 8, 3], [0.2631578947368421, 10, -1], [0.10526315789473684, 11, -2], [0.05263157894736842, 12, 4], [0.05263157894736842, 14, 3]], 13: [[0.1111111111111111, 1, -1], [0.1111111111111111, 2, 0], [0.1111111111111111, 5, 0], [0.1111111111111111, 6, 0], [0.3333333333333333, 10, 5], [0.2222222222222222, 11, 8]], 14: [[0.125, 2, 6], [0.16666666666666666, 3, 2], [0.041666666666666664, 4, 1], [0.08333333333333333, 5, 1], [0.125, 6, -1], [0.125, 7, 5], [0.16666666666666666, 10, 2], [0.08333333333333333, 11, 0], [0.08333333333333333, 14, 0]]}

# %%
def write_csv(directory_name, avg_reward_aa, avg_reward_ae):
    data = [directory_name, avg_reward_aa, avg_reward_ae]
    with open('trials/summary.csv', mode='a', newline='') as file:
        writer = csv.writer(file)
        #writer.writerow(header)
        writer.writerow(data)

# %% [markdown]
# ### Create action-per-action environment

# %% [markdown]
# ## Q-Learning off-policy TD Training

# %%
bst_alpha = 0.2
bst_gamma = 0.4 # or 0.6
bst_td = 2

history = { "aa_history" : [],
            "ae_history" : []}

gamma = bst_gamma
epsilon = 0.1
min_difference = 0.000001 # 10^-7
td_step = 14
alpha = bst_alpha

hyperparameters = []
#a = [i / 100.0 for i in range(0,21, 2)]
g = [i / 100.0 for i in range(0,61, 10)]
td = range(0, 16, 1)

for idx, elem in enumerate(g):
    if train:
        hp = {  "gamma" : elem,
                "alpha": alpha,
                "td_step": td_step,
                "epsilon_min": epsilon}
        hyperparameters.append(hp)
        env = ImprobotEnv(actor_space=ACTIONS,robot_space=ACTIONS,sketch_lenght=15,env_matrix=P_aa, P0=P0)
        double_q_learning_train(alpha=alpha,gamma=elem,epsilon=epsilon, TD_step=td_step,min_q_diff=min_difference,env=env)
        history["aa_history"].append(policy_eval(env))

max_idx = np.argmax(history["aa_history"])
avg_reward_aa = history["aa_history"][max_idx]
directory_name = model_name + "bst_aa" + "_hp_gm_" + str(hyperparameters[max_idx]["gamma"]) + "_alph_" + str(hyperparameters[max_idx]["alpha"]) + "_td_" + str(hyperparameters[max_idx]["td_step"]) + "_eps_" + str(hyperparameters[max_idx]["epsilon_min"])
write_csv(directory_name, avg_reward_aa, 0)
# Out:
# Episode: 100
# action choosen: 14
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 200
# action choosen: 11
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 300
# action choosen: 10
# next_state: (10, 2)
# q_value updated: 0.0
# Episode: 400
# action choosen: 5
# next_state: (14, 2)
# q_value updated: 0.0
# Episode: 500
# action choosen: 3
# next_state: (7, 3)
# q_value updated: 0.0
# Episode: 600
# action choosen: 7
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 700
# action choosen: 7
# next_state: (11, 8)
# q_value updated: 0.0
# Episode: 800
# action choosen: 10
# next_state: (6, 3)
# q_value updated: 0.0
# Episode: 900
# action choosen: 12
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 1000
# action choosen: 8
# next_state: (6, 14)
# q_value updated: 0.0
# Episode: 1100
# action choosen: 4
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 1200
# action choosen: 6
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 1300
# action choosen: 6
# next_state: (2, 2)
# q_value updated: 0.0
# Episode: 1400
# action choosen: 12
# next_state: (9, 6)
# q_value updated: 0.0
# Episode: 1500
# action choosen: 12
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 1600
# action choosen: 13
# next_state: (8, 3)
# q_value updated: 0.0
# Episode: 1700
# action choosen: 13
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 1800
# action choosen: 13
# next_state: (14, 10)
# q_value updated: 0.0
# Episode: 1900
# action choosen: 5
# next_state: (8, 5)
# q_value updated: 0.0
# Episode: 2000
# action choosen: 5
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 2100
# action choosen: 5
# next_state: (7, 12)
# q_value updated: 0.0
# Episode: 2200
# action choosen: 3
# next_state: (11, 11)
# q_value updated: 0.0
# Episode: 2300
# action choosen: 11
# next_state: (11, 13)
# q_value updated: 0.0
# Episode: 2400
# action choosen: 12
# next_state: (7, 12)
# q_value updated: 0.0
# Episode: 2500
# action choosen: 4
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 2600
# action choosen: 9
# next_state: (5, 13)
# q_value updated: 0.0
# Episode: 2700
# action choosen: 12
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 2800
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 2900
# action choosen: 3
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 3000
# action choosen: 13
# next_state: (11, 6)
# q_value updated: 0.0
# Episode: 3100
# action choosen: 9
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 3200
# action choosen: 14
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 3300
# action choosen: 10
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 3400
# action choosen: 4
# next_state: (6, 2)
# q_value updated: 0.0
# Episode: 3500
# action choosen: 9
# next_state: (12, 12)
# q_value updated: 0.0
# Episode: 3600
# action choosen: 1
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 3700
# action choosen: 14
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 3800
# action choosen: 8
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 3900
# action choosen: 1
# next_state: (2, 2)
# q_value updated: 0.0
# Episode: 4000
# action choosen: 12
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 4100
# action choosen: 10
# next_state: (14, 5)
# q_value updated: 0.0
# Episode: 4200
# action choosen: 2
# next_state: (5, 13)
# q_value updated: 0.0
# Episode: 4300
# action choosen: 1
# next_state: (8, 3)
# q_value updated: 0.0
# Episode: 4400
# action choosen: 5
# next_state: (4, 11)
# q_value updated: 0.0
# Episode: 4500
# action choosen: 10
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 4600
# action choosen: 3
# next_state: (10, 3)
# q_value updated: 0.0
# Episode: 4700
# action choosen: 10
# next_state: (7, 12)
# q_value updated: 0.0
# Episode: 4800
# action choosen: 12
# next_state: (6, 5)
# q_value updated: 0.0
# Episode: 4900
# action choosen: 1
# next_state: (14, 10)
# q_value updated: 0.0
# Episode: 5000
# action choosen: 7
# next_state: (14, 10)
# q_value updated: 0.0
# Episode: 5100
# action choosen: 9
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 5200
# action choosen: 8
# next_state: (10, 3)
# q_value updated: 0.0
# Episode: 5300
# action choosen: 10
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 5400
# action choosen: 8
# next_state: (7, 11)
# q_value updated: 0.0
# Episode: 5500
# action choosen: 14
# next_state: (3, 3)
# q_value updated: 0.0
# Episode: 5600
# action choosen: 10
# next_state: (7, 7)
# q_value updated: 0.0
# Episode: 5700
# action choosen: 1
# next_state: (11, 11)
# q_value updated: 0.0
# Episode: 5800
# action choosen: 8
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 5900
# action choosen: 6
# next_state: (10, 2)
# q_value updated: 0.0
# Episode: 6000
# action choosen: 1
# next_state: (12, 11)
# q_value updated: 0.0
# Episode: 6100
# action choosen: 7
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 6200
# action choosen: 14
# next_state: (14, 6)
# q_value updated: 0.0
# Episode: 6300
# action choosen: 10
# next_state: (14, 3)
# q_value updated: 0.0
# Episode: 6400
# action choosen: 8
# next_state: (11, 4)
# q_value updated: 0.0
# Episode: 6500
# action choosen: 7
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 6600
# action choosen: 2
# next_state: (11, 11)
# q_value updated: 0.0
# Episode: 6700
# action choosen: 5
# next_state: (7, 12)
# q_value updated: 0.0
# Episode: 6800
# action choosen: 5
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 6900
# action choosen: 12
# next_state: (14, 2)
# q_value updated: 0.0
# Episode: 7000
# action choosen: 14
# next_state: (13, 1)
# q_value updated: 0.0
# Episode: 7100
# action choosen: 12
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 7200
# action choosen: 1
# next_state: (3, 6)
# q_value updated: 0.0
# Episode: 7300
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 7400
# action choosen: 10
# next_state: (14, 11)
# q_value updated: 0.0
# Episode: 7500
# action choosen: 4
# next_state: (11, 6)
# q_value updated: 0.0
# Episode: 7600
# action choosen: 14
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 7700
# action choosen: 10
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 7800
# action choosen: 14
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 7900
# action choosen: 2
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 8000
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 8100
# action choosen: 9
# next_state: (5, 6)
# q_value updated: 0.0
# Episode: 8200
# action choosen: 3
# next_state: (3, 8)
# q_value updated: 0.0
# Episode: 8300
# action choosen: 13
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 8400
# action choosen: 2
# next_state: (5, 6)
# q_value updated: 0.0
# Episode: 8500
# action choosen: 10
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 8600
# action choosen: 7
# next_state: (3, 6)
# q_value updated: 0.0
# Episode: 8700
# action choosen: 13
# next_state: (12, 11)
# q_value updated: 0.0
# Episode: 8800
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 8900
# action choosen: 2
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 9000
# action choosen: 11
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 9100
# action choosen: 2
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 9200
# action choosen: 1
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 9300
# action choosen: 7
# next_state: (4, 11)
# q_value updated: 0.0
# Episode: 9400
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 9500
# action choosen: 12
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 9600
# action choosen: 14
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 9700
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 9800
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 9900
# action choosen: 11
# next_state: (6, 12)
# q_value updated: 0.0
# Episode: 10000
# action choosen: 11
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 10100
# action choosen: 14
# next_state: (6, 12)
# q_value updated: 0.0
# Episode: 10200
# action choosen: 9
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 10300
# action choosen: 5
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 10400
# action choosen: 8
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 10500
# action choosen: 1
# next_state: (6, 8)
# q_value updated: 0.0
# Episode: 10600
# action choosen: 4
# next_state: (10, 8)
# q_value updated: 0.0
# Episode: 10700
# action choosen: 1
# next_state: (10, 4)
# q_value updated: 0.0
# Episode: 10800
# action choosen: 3
# next_state: (13, 1)
# q_value updated: 0.0
# Episode: 10900
# action choosen: 12
# next_state: (6, 3)
# q_value updated: 0.0
# Episode: 11000
# action choosen: 6
# next_state: (12, 12)
# q_value updated: 0.0
# Episode: 11100
# action choosen: 5
# next_state: (11, 8)
# q_value updated: 0.0
# Episode: 11200
# action choosen: 9
# next_state: (3, 3)
# q_value updated: 0.0
# Episode: 11300
# action choosen: 10
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 11400
# action choosen: 12
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 11500
# action choosen: 3
# next_state: (11, 6)
# q_value updated: 0.0
# Episode: 11600
# action choosen: 9
# next_state: (5, 5)
# q_value updated: 0.0
# Episode: 11700
# action choosen: 6
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 11800
# action choosen: 13
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 11900
# action choosen: 1
# next_state: (13, 6)
# q_value updated: 0.0
# Episode: 12000
# action choosen: 13
# next_state: (7, 11)
# q_value updated: 0.0
# Episode: 12100
# action choosen: 5
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 12200
# action choosen: 5
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 12300
# action choosen: 14
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 12400
# action choosen: 1
# next_state: (2, 11)
# q_value updated: 0.0
# Episode: 12500
# action choosen: 7
# next_state: (11, 6)
# q_value updated: 0.0
# Episode: 12600
# action choosen: 8
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 12700
# action choosen: 4
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 12800
# action choosen: 7
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 12900
# action choosen: 12
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 13000
# action choosen: 5
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 13100
# action choosen: 11
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 13200
# action choosen: 2
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 13300
# action choosen: 9
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 13400
# action choosen: 14
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 13500
# action choosen: 11
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 13600
# action choosen: 4
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 13700
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 13800
# action choosen: 5
# next_state: (2, 2)
# q_value updated: 0.0
# Episode: 13900
# action choosen: 1
# next_state: (11, 5)
# q_value updated: 0.0
# Episode: 14000
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 14100
# action choosen: 13
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 14200
# action choosen: 1
# next_state: (3, 8)
# q_value updated: 0.0
# Episode: 14300
# action choosen: 12
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 14400
# action choosen: 5
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 14500
# action choosen: 5
# next_state: (14, 14)
# q_value updated: 0.0
# Episode: 14600
# action choosen: 7
# next_state: (7, 7)
# q_value updated: 0.0
# Episode: 14700
# action choosen: 10
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 14800
# action choosen: 10
# next_state: (5, 10)
# q_value updated: 0.0
# Episode: 14900
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 15000
# action choosen: 6
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 15100
# action choosen: 9
# next_state: (7, 3)
# q_value updated: 0.0
# Episode: 15200
# action choosen: 1
# next_state: (3, 4)
# q_value updated: 0.0
# Episode: 15300
# action choosen: 2
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 15400
# action choosen: 2
# next_state: (6, 11)
# q_value updated: 0.0
# Episode: 15500
# action choosen: 12
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 15600
# action choosen: 8
# next_state: (2, 1)
# q_value updated: 0.0
# Episode: 15700
# action choosen: 9
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 15800
# action choosen: 7
# next_state: (3, 7)
# q_value updated: 0.0
# Episode: 15900
# action choosen: 9
# next_state: (4, 8)
# q_value updated: 0.0
# Episode: 16000
# action choosen: 10
# next_state: (3, 7)
# q_value updated: 0.0
# Episode: 16100
# action choosen: 7
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 16200
# action choosen: 11
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 16300
# action choosen: 1
# next_state: (3, 3)
# q_value updated: 0.0
# Episode: 16400
# action choosen: 7
# next_state: (10, 4)
# q_value updated: 0.0
# Episode: 16500
# action choosen: 10
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 16600
# action choosen: 12
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 16700
# action choosen: 11
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 16800
# action choosen: 10
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 16900
# action choosen: 12
# next_state: (13, 5)
# q_value updated: 0.0
# Episode: 17000
# action choosen: 7
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 17100
# action choosen: 7
# next_state: (6, 12)
# q_value updated: 0.0
# Episode: 17200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 17300
# action choosen: 6
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 17400
# action choosen: 14
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 17500
# action choosen: 8
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 17600
# action choosen: 13
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 17700
# action choosen: 3
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 17800
# action choosen: 1
# next_state: (5, 10)
# q_value updated: 0.0
# Episode: 17900
# action choosen: 8
# next_state: (12, 6)
# q_value updated: 0.0
# Episode: 18000
# action choosen: 1
# next_state: (7, 7)
# q_value updated: 0.0
# Episode: 18100
# action choosen: 2
# next_state: (10, 3)
# q_value updated: 0.0
# Episode: 18200
# action choosen: 4
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 18300
# action choosen: 1
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 18400
# action choosen: 11
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 18500
# action choosen: 7
# next_state: (7, 7)
# q_value updated: 0.0
# Episode: 18600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 18700
# action choosen: 1
# next_state: (13, 1)
# q_value updated: 0.0
# Episode: 18800
# action choosen: 8
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 18900
# action choosen: 6
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 19000
# action choosen: 7
# next_state: (9, 6)
# q_value updated: 0.0
# Episode: 19100
# action choosen: 1
# next_state: (4, 3)
# q_value updated: 0.0
# Episode: 19200
# action choosen: 9
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 19300
# action choosen: 9
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 19400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 19500
# action choosen: 1
# next_state: (14, 10)
# q_value updated: 0.0
# Episode: 19600
# action choosen: 12
# next_state: (8, 3)
# q_value updated: 0.0
# Episode: 19700
# action choosen: 10
# next_state: (10, 8)
# q_value updated: 0.0
# Episode: 19800
# action choosen: 11
# next_state: (3, 6)
# q_value updated: 0.0
# Episode: 19900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 20000
# action choosen: 12
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 20100
# action choosen: 10
# next_state: (7, 7)
# q_value updated: 0.0
# Episode: 20200
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 20300
# action choosen: 6
# next_state: (9, 6)
# q_value updated: 0.0
# Episode: 20400
# action choosen: 1
# next_state: (5, 11)
# q_value updated: 0.0
# Episode: 20500
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 20600
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 20700
# action choosen: 10
# next_state: (10, 8)
# q_value updated: 0.0
# Episode: 20800
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 20900
# action choosen: 13
# next_state: (5, 8)
# q_value updated: 0.0
# Episode: 21000
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 21100
# action choosen: 14
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 21200
# action choosen: 1
# next_state: (3, 5)
# q_value updated: 0.0
# Episode: 21300
# action choosen: 1
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 21400
# action choosen: 5
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 21500
# action choosen: 4
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 21600
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 21700
# action choosen: 1
# next_state: (7, 3)
# q_value updated: 0.0
# Episode: 21800
# action choosen: 5
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 21900
# action choosen: 11
# next_state: (6, 12)
# q_value updated: 0.0
# Episode: 22000
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 22100
# action choosen: 6
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 22200
# action choosen: 2
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 22300
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 22400
# action choosen: 5
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 22500
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 22600
# action choosen: 1
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 22700
# action choosen: 6
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 22800
# action choosen: 4
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 22900
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 23000
# action choosen: 8
# next_state: (4, 11)
# q_value updated: 0.0
# Episode: 23100
# action choosen: 2
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 23200
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 23300
# action choosen: 6
# next_state: (3, 3)
# q_value updated: 0.0
# Episode: 23400
# action choosen: 1
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 23500
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 23600
# action choosen: 1
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 23700
# action choosen: 2
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 23800
# action choosen: 1
# next_state: (7, 11)
# q_value updated: 0.0
# Episode: 23900
# action choosen: 10
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 24000
# action choosen: 2
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 24100
# action choosen: 13
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 24200
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 24300
# action choosen: 12
# next_state: (14, 7)
# q_value updated: 0.0
# Episode: 24400
# action choosen: 9
# next_state: (10, 6)
# q_value updated: 0.0
# Episode: 24500
# action choosen: 5
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 24600
# action choosen: 10
# next_state: (12, 7)
# q_value updated: 0.0
# Episode: 24700
# action choosen: 14
# next_state: (6, 12)
# q_value updated: 0.0
# Episode: 24800
# action choosen: 1
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 24900
# action choosen: 14
# next_state: (4, 8)
# q_value updated: 0.0
# Episode: 25000
# action choosen: 1
# next_state: (12, 6)
# q_value updated: 0.0
# Episode: 25100
# action choosen: 14
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 25200
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 25300
# action choosen: 13
# next_state: (12, 6)
# q_value updated: 0.0
# Episode: 25400
# action choosen: 4
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 25500
# action choosen: 6
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 25600
# action choosen: 5
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 25700
# action choosen: 13
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 25800
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 25900
# action choosen: 5
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 26000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 26100
# action choosen: 4
# next_state: (5, 8)
# q_value updated: 0.0
# Episode: 26200
# action choosen: 6
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 26300
# action choosen: 1
# next_state: (5, 5)
# q_value updated: 0.0
# Episode: 26400
# action choosen: 3
# next_state: (2, 14)
# q_value updated: 0.0
# Episode: 26500
# action choosen: 1
# next_state: (3, 5)
# q_value updated: 0.0
# Episode: 26600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 26700
# action choosen: 13
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 26800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 26900
# action choosen: 5
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 27000
# action choosen: 9
# next_state: (11, 13)
# q_value updated: 0.0
# Episode: 27100
# action choosen: 12
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 27200
# action choosen: 11
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 27300
# action choosen: 1
# next_state: (9, 6)
# q_value updated: 0.0
# Episode: 27400
# action choosen: 1
# next_state: (10, 2)
# q_value updated: 0.0
# Episode: 27500
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 27600
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 27700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 27800
# action choosen: 14
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 27900
# action choosen: 6
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 28000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 28100
# action choosen: 1
# next_state: (5, 6)
# q_value updated: 0.0
# Episode: 28200
# action choosen: 10
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 28300
# action choosen: 1
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 28400
# action choosen: 14
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 28500
# action choosen: 8
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 28600
# action choosen: 7
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 28700
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 28800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 28900
# action choosen: 2
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 29000
# action choosen: 6
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 29100
# action choosen: 9
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 29200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 29300
# action choosen: 2
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 29400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 29500
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 29600
# action choosen: 1
# next_state: (14, 5)
# q_value updated: 0.0
# Episode: 29700
# action choosen: 1
# next_state: (9, 6)
# q_value updated: 0.0
# Episode: 29800
# action choosen: 4
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 29900
# action choosen: 8
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 30000
# action choosen: 1
# next_state: (3, 6)
# q_value updated: 0.0
# Episode: 30100
# action choosen: 12
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 30200
# action choosen: 1
# next_state: (10, 8)
# q_value updated: 0.0
# Episode: 30300
# action choosen: 1
# next_state: (2, 1)
# q_value updated: 0.0
# Episode: 30400
# action choosen: 12
# next_state: (3, 3)
# q_value updated: 0.0
# Episode: 30500
# action choosen: 6
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 30600
# action choosen: 1
# next_state: (4, 3)
# q_value updated: 0.0
# Episode: 30700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 30800
# action choosen: 5
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 30900
# action choosen: 7
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 31000
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 31100
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 31200
# action choosen: 13
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 31300
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 31400
# action choosen: 6
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 31500
# action choosen: 1
# next_state: (4, 3)
# q_value updated: 0.0
# Episode: 31600
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 31700
# action choosen: 2
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 31800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 31900
# action choosen: 1
# next_state: (10, 10)
# q_value updated: 0.0
# Episode: 32000
# action choosen: 11
# next_state: (7, 3)
# q_value updated: 0.0
# Episode: 32100
# action choosen: 1
# next_state: (14, 3)
# q_value updated: 0.0
# Episode: 32200
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 32300
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 32400
# action choosen: 1
# next_state: (13, 6)
# q_value updated: 0.0
# Episode: 32500
# action choosen: 1
# next_state: (8, 5)
# q_value updated: 0.0
# Episode: 32600
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 32700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 32800
# action choosen: 7
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 32900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 33000
# action choosen: 13
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 33100
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 33200
# action choosen: 14
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 33300
# action choosen: 5
# next_state: (6, 14)
# q_value updated: 0.0
# Episode: 33400
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 33500
# action choosen: 2
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 33600
# action choosen: 9
# next_state: (2, 10)
# q_value updated: 0.0
# Episode: 33700
# action choosen: 9
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 33800
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 33900
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 34000
# action choosen: 13
# next_state: (4, 8)
# q_value updated: 0.0
# Episode: 34100
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 34200
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 34300
# action choosen: 4
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 34400
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 34500
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 34600
# action choosen: 6
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 34700
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 34800
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 34900
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 35000
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 35100
# action choosen: 4
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 35200
# action choosen: 13
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 35300
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 35400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 35500
# action choosen: 10
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 35600
# action choosen: 7
# next_state: (10, 12)
# q_value updated: 0.0
# Episode: 35700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 35800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 35900
# action choosen: 1
# next_state: (14, 10)
# q_value updated: 0.0
# Episode: 36000
# action choosen: 1
# next_state: (7, 11)
# q_value updated: 0.0
# Episode: 36100
# action choosen: 1
# next_state: (11, 5)
# q_value updated: 0.0
# Episode: 36200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 36300
# action choosen: 1
# next_state: (6, 2)
# q_value updated: 0.0
# Episode: 36400
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 36500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 36600
# action choosen: 3
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 36700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 36800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 36900
# action choosen: 12
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 37000
# action choosen: 1
# next_state: (6, 5)
# q_value updated: 0.0
# Episode: 37100
# action choosen: 8
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 37200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 37300
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 37400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 37500
# action choosen: 12
# next_state: (6, 11)
# q_value updated: 0.0
# Episode: 37600
# action choosen: 14
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 37700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 37800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 37900
# action choosen: 1
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 38000
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 38100
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 38200
# action choosen: 13
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 38300
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 38400
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 38500
# action choosen: 13
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 38600
# action choosen: 1
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 38700
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 38800
# action choosen: 5
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 38900
# action choosen: 11
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 39000
# action choosen: 1
# next_state: (2, 14)
# q_value updated: 0.0
# Episode: 39100
# action choosen: 8
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 39200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 39300
# action choosen: 1
# next_state: (8, 5)
# q_value updated: 0.0
# Episode: 39400
# action choosen: 6
# next_state: (5, 2)
# q_value updated: 0.0
# Episode: 39500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 39600
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 39700
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 39800
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 39900
# action choosen: 1
# next_state: (14, 11)
# q_value updated: 0.0
# Episode: 40000
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 40100
# action choosen: 3
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 40200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 40300
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 40400
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 40500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 40600
# action choosen: 4
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 40700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 40800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 40900
# action choosen: 1
# next_state: (13, 11)
# q_value updated: 0.0
# Episode: 41000
# action choosen: 1
# next_state: (3, 6)
# q_value updated: 0.0
# Episode: 41100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 41200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 41300
# action choosen: 1
# next_state: (13, 5)
# q_value updated: 0.0
# Episode: 41400
# action choosen: 1
# next_state: (10, 8)
# q_value updated: 0.0
# Episode: 41500
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 41600
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 41700
# action choosen: 1
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 41800
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 41900
# action choosen: 2
# next_state: (2, 14)
# q_value updated: 0.0
# Episode: 42000
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 42100
# action choosen: 4
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 42200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 42300
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 42400
# action choosen: 1
# next_state: (5, 10)
# q_value updated: 0.0
# Episode: 42500
# action choosen: 1
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 42600
# action choosen: 1
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 42700
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 42800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 42900
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 43000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 43100
# action choosen: 7
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 43200
# action choosen: 11
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 43300
# action choosen: 6
# next_state: (5, 8)
# q_value updated: 0.0
# Episode: 43400
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 43500
# action choosen: 1
# next_state: (7, 10)
# q_value updated: 0.0
# Episode: 43600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 43700
# action choosen: 11
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 43800
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 43900
# action choosen: 1
# next_state: (4, 10)
# q_value updated: 0.0
# Episode: 44000
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 44100
# action choosen: 1
# next_state: (8, 7)
# q_value updated: 0.0
# Episode: 44200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 44300
# action choosen: 1
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 44400
# action choosen: 9
# next_state: (10, 2)
# q_value updated: 0.0
# Episode: 44500
# action choosen: 9
# next_state: (9, 10)
# q_value updated: 0.0
# Episode: 44600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 44700
# action choosen: 3
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 44800
# action choosen: 1
# next_state: (14, 4)
# q_value updated: 0.0
# Episode: 44900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 45000
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 45100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 45200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 45300
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 45400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 45500
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 45600
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 45700
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 45800
# action choosen: 1
# next_state: (2, 8)
# q_value updated: 0.0
# Episode: 45900
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 46000
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 46100
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 46200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 46300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 46400
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 46500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 46600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 46700
# action choosen: 1
# next_state: (11, 6)
# q_value updated: 0.0
# Episode: 46800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 46900
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 47000
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 47100
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 47200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 47300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 47400
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 47500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 47600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 47700
# action choosen: 2
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 47800
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 47900
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 48000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 48100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48200
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48400
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 48500
# action choosen: 6
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 48600
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48700
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48800
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 48900
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 49000
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 49100
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 49200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 49300
# action choosen: 12
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 49400
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 49500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 49600
# action choosen: 10
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 49700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 49800
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 49900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 50000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 50100
# action choosen: 14
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 50200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 50300
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 50400
# action choosen: 4
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 50500
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 50600
# action choosen: 12
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 50700
# action choosen: 13
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 50800
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 50900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 51000
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 51100
# action choosen: 1
# next_state: (8, 10)
# q_value updated: 0.0
# Episode: 51200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 51300
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 51400
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 51500
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 51600
# action choosen: 1
# next_state: (13, 2)
# q_value updated: 0.0
# Episode: 51700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 51800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 51900
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 52000
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 52100
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 52200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 52300
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 52400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 52500
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 52600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 52700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 52800
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 52900
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 53000
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 53100
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 53200
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 53300
# action choosen: 7
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 53400
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 53500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 53600
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 53700
# action choosen: 1
# next_state: (13, 10)
# q_value updated: 0.0
# Episode: 53800
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 53900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 54000
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 54100
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 54200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 54300
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 54400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 54500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 54600
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 54700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 54800
# action choosen: 14
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 54900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 55000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 55100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 55200
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 55300
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 55400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 55500
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 55600
# action choosen: 1
# next_state: (8, 7)
# q_value updated: 0.0
# Episode: 55700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 55800
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 55900
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 56000
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 56100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 56200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 56300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 56400
# action choosen: 1
# next_state: (13, 1)
# q_value updated: 0.0
# Episode: 56500
# action choosen: 1
# next_state: (8, 8)
# q_value updated: 0.0
# Episode: 56600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 56700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 56800
# action choosen: 13
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 56900
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 57000
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 57100
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 57200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 57300
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 57400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 57500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 57600
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 57700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 57800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 57900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 58000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 58100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 58200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 58300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 58400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 58500
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 58600
# action choosen: 11
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 58700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 58800
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 58900
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 59000
# action choosen: 5
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 59100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 59200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 59300
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 59400
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 59500
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 59600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 59700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 59800
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 59900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 60000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 60100
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 60200
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 60300
# action choosen: 1
# next_state: (12, 10)
# q_value updated: 0.0
# Episode: 60400
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 60500
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 60600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 60700
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 60800
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 60900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 61000
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 61100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 61200
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 61300
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 61400
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 61500
# action choosen: 2
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 61600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 61700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 61800
# action choosen: 12
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 61900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 62000
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 62100
# action choosen: 1
# next_state: (3, 10)
# q_value updated: 0.0
# Episode: 62200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 62300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 62400
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 62500
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 62600
# action choosen: 1
# next_state: (5, 10)
# q_value updated: 0.0
# Episode: 62700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 62800
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 62900
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 63000
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 63100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 63200
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 63300
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 63400
# action choosen: 1
# next_state: (8, 3)
# q_value updated: 0.0
# Episode: 63500
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 63600
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 0.0
# Episode: 63700
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 63800
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 0.0
# Episode: 63900
# action choosen: 1
# next_state: (6, 6)
# q_value updated: 0.0
# Episode: 64000
# action choosen: 1
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 64100
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 64200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 64300
# action choosen: 1
# next_state: (11, 10)
# q_value updated: 0.0
# Episode: 64400
# action choosen: 1
# next_state: (1, 7)
# q_value updated: 0.0
# Episode: 64500
# action choosen: 14
# next_state: (1, 11)
# q_value updated: 0.0
# Episode: 64600
# action choosen: 1
# next_state: (6, 11)
# q_value updated: 0.0
# Episode: 64700
# action choosen: 1
# next_state: (13, 5)
# q_value updated: 0.0
# Episode: 64800
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 0.0
# Episode: 64900
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 65000
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.0
# Episode: 65100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 0.0
# Episode: 65200
# action choosen: 1
# next_state: (1, 7)
# ...
# Episode: 82000
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 24.86156930374598
# Episode: 82100
# action choosen: 12
# next_state: (6, 6)
# q_value updated: 23.444682168059863
# Episode: 82200
# action choosen: 2
# next_state: (6, 14)
# q_value updated: 34.14150802303102
# Episode: 82300
# action choosen: 6
# next_state: (4, 3)
# q_value updated: 29.675969034780792
# Episode: 82400
# action choosen: 5
# next_state: (3, 6)
# q_value updated: 28.68843917367056
# Episode: 82500
# action choosen: 5
# next_state: (3, 3)
# q_value updated: 29.138743495032124
# Episode: 82600
# action choosen: 10
# next_state: (13, 10)
# q_value updated: 17.01432728999676
# Episode: 82700
# action choosen: 6
# next_state: (6, 8)
# q_value updated: 16.98381034579428
# Episode: 82800
# action choosen: 6
# next_state: (5, 2)
# q_value updated: 28.23878443829362
# Episode: 82900
# action choosen: 6
# next_state: (6, 3)
# q_value updated: 18.400643320959087
# Episode: 83000
# action choosen: 8
# next_state: (2, 14)
# q_value updated: 17.761270459980835
# Episode: 83100
# action choosen: 8
# next_state: (9, 10)
# q_value updated: 28.99677361503084
# Episode: 83200
# action choosen: 5
# next_state: (14, 7)
# q_value updated: 29.71705043454346
# Episode: 83300
# action choosen: 7
# next_state: (3, 6)
# q_value updated: 26.94465704969886
# Episode: 83400
# action choosen: 5
# next_state: (6, 3)
# q_value updated: 21.016359228736135
# Episode: 83500
# action choosen: 12
# next_state: (2, 10)
# q_value updated: 26.380634852211088
# Episode: 83600
# action choosen: 7
# next_state: (2, 8)
# q_value updated: 28.325393890217132
# Episode: 83700
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 31.4782123662324
# Episode: 83800
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 22.09999545562669
# Episode: 83900
# action choosen: 6
# next_state: (1, 8)
# q_value updated: 24.815729388924556
# Episode: 84000
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 21.10763421575244
# Episode: 84100
# action choosen: 8
# next_state: (5, 8)
# q_value updated: 34.37388195743782
# Episode: 84200
# action choosen: 3
# next_state: (3, 7)
# q_value updated: 19.457837131603878
# Episode: 84300
# action choosen: 5
# next_state: (8, 5)
# q_value updated: 16.327862757821507
# Episode: 84400
# action choosen: 3
# next_state: (6, 14)
# q_value updated: 24.312525136227464
# Episode: 84500
# action choosen: 5
# next_state: (2, 14)
# q_value updated: 18.12344957518475
# Episode: 84600
# action choosen: 4
# next_state: (11, 6)
# q_value updated: 22.841077964775256
# Episode: 84700
# action choosen: 6
# next_state: (1, 5)
# q_value updated: 33.80893359293477
# Episode: 84800
# action choosen: 7
# next_state: (5, 6)
# q_value updated: 17.607401890160787
# Episode: 84900
# action choosen: 3
# next_state: (2, 10)
# q_value updated: 15.759220232023353
# Episode: 85000
# action choosen: 3
# next_state: (6, 3)
# q_value updated: 18.70309488173476
# Episode: 85100
# action choosen: 6
# next_state: (3, 10)
# q_value updated: 16.049870670955485
# Episode: 85200
# action choosen: 9
# next_state: (7, 3)
# q_value updated: 28.120950135529206
# Episode: 85300
# action choosen: 5
# next_state: (5, 13)
# q_value updated: 25.888320642022194
# Episode: 85400
# action choosen: 7
# next_state: (13, 10)
# q_value updated: 25.51186151237996
# Episode: 85500
# action choosen: 4
# next_state: (3, 10)
# q_value updated: 15.037259543165627
# Episode: 85600
# action choosen: 2
# next_state: (5, 6)
# q_value updated: 19.670349747844085
# Episode: 85700
# action choosen: 6
# next_state: (3, 6)
# q_value updated: 23.62135966177391
# Episode: 85800
# action choosen: 5
# next_state: (2, 1)
# q_value updated: 25.159031040574472
# Episode: 85900
# action choosen: 3
# next_state: (6, 12)
# q_value updated: 13.968454675966704
# Episode: 86000
# action choosen: 10
# next_state: (6, 2)
# q_value updated: 20.28021712939233
# Episode: 86100
# action choosen: 8
# next_state: (6, 8)
# q_value updated: 25.695470238262107
# Episode: 86200
# action choosen: 3
# next_state: (9, 10)
# q_value updated: 25.758830175502744
# Episode: 86300
# action choosen: 2
# next_state: (8, 3)
# q_value updated: 21.683911215328884
# Episode: 86400
# action choosen: 3
# next_state: (7, 10)
# q_value updated: 20.73442226494906
# Episode: 86500
# action choosen: 6
# next_state: (12, 8)
# q_value updated: 15.80024662162756
# Episode: 86600
# action choosen: 2
# next_state: (6, 6)
# q_value updated: 21.051511503784038
# Episode: 86700
# action choosen: 7
# next_state: (6, 11)
# q_value updated: 24.75339982077519
# Episode: 86800
# action choosen: 5
# next_state: (4, 3)
# q_value updated: 22.270711872823405
# Episode: 86900
# action choosen: 4
# next_state: (2, 11)
# q_value updated: 20.7707209465676
# Episode: 87000
# action choosen: 8
# next_state: (13, 11)
# q_value updated: 21.40209008858287
# Episode: 87100
# action choosen: 12
# next_state: (10, 2)
# q_value updated: 19.224695347188494
# Episode: 87200
# action choosen: 11
# next_state: (5, 10)
# q_value updated: 32.00353074063119
# Episode: 87300
# action choosen: 8
# next_state: (12, 6)
# q_value updated: 28.729104019112903
# Episode: 87400
# action choosen: 7
# next_state: (13, 11)
# q_value updated: 19.438949097609562
# Episode: 87500
# action choosen: 6
# next_state: (5, 6)
# q_value updated: 24.791913066680095
# Episode: 87600
# action choosen: 6
# next_state: (5, 6)
# q_value updated: 24.398607503230412
# Episode: 87700
# action choosen: 5
# next_state: (10, 3)
# q_value updated: 26.803550284928214
# Episode: 87800
# action choosen: 13
# next_state: (8, 3)
# q_value updated: 20.24070172298108
# Episode: 87900
# action choosen: 8
# next_state: (11, 11)
# q_value updated: 19.35060344645126
# Episode: 88000
# action choosen: 5
# next_state: (6, 5)
# q_value updated: 28.250514860600624
# Episode: 88100
# action choosen: 2
# next_state: (4, 8)
# q_value updated: 19.66827125797262
# Episode: 88200
# action choosen: 11
# next_state: (8, 3)
# q_value updated: 21.564051466077306
# Episode: 88300
# action choosen: 3
# next_state: (5, 13)
# q_value updated: 18.931226098705697
# Episode: 88400
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 22.152991731292325
# Episode: 88500
# action choosen: 5
# next_state: (3, 3)
# q_value updated: 31.889856688401505
# Episode: 88600
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 28.317127871905363
# Episode: 88700
# action choosen: 6
# next_state: (5, 8)
# q_value updated: 22.24923769238811
# Episode: 88800
# action choosen: 8
# next_state: (6, 5)
# q_value updated: 26.901401258605006
# Episode: 88900
# action choosen: 3
# next_state: (13, 10)
# q_value updated: 25.16243809499928
# Episode: 89000
# action choosen: 2
# next_state: (8, 10)
# q_value updated: 24.10912416129265
# Episode: 89100
# action choosen: 5
# next_state: (2, 11)
# q_value updated: 31.82049561896655
# Episode: 89200
# action choosen: 4
# next_state: (6, 6)
# q_value updated: 31.45588479321197
# Episode: 89300
# action choosen: 9
# next_state: (5, 8)
# q_value updated: 10.413857435490263
# Episode: 89400
# action choosen: 8
# next_state: (11, 11)
# q_value updated: 31.32523860045546
# Episode: 89500
# action choosen: 8
# next_state: (2, 10)
# q_value updated: 23.48004422092164
# Episode: 89600
# action choosen: 2
# next_state: (3, 3)
# q_value updated: 29.111692412521066
# Episode: 89700
# action choosen: 5
# next_state: (6, 6)
# q_value updated: 35.38839714559136
# Episode: 89800
# action choosen: 5
# next_state: (5, 5)
# q_value updated: 26.23414626420744
# Episode: 89900
# action choosen: 6
# next_state: (13, 5)
# q_value updated: 27.428819071577642
# Episode: 90000
# action choosen: 4
# next_state: (3, 8)
# q_value updated: 20.721578443042112
# Episode: 90100
# action choosen: 5
# next_state: (2, 2)
# q_value updated: 28.06882984997289
# Episode: 90200
# action choosen: 2
# next_state: (3, 3)
# q_value updated: 27.354135754895463
# Episode: 90300
# action choosen: 3
# next_state: (8, 10)
# q_value updated: 32.83557528065141
# Episode: 90400
# action choosen: 6
# next_state: (6, 5)
# q_value updated: 19.40923910763756
# Episode: 90500
# action choosen: 14
# next_state: (13, 6)
# q_value updated: 16.67196999674105
# Episode: 90600
# action choosen: 2
# next_state: (6, 6)
# q_value updated: 20.06150322161688
# Episode: 90700
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 20.60421429376955
# Episode: 90800
# action choosen: 6
# next_state: (5, 10)
# q_value updated: 26.164416400507818
# Episode: 90900
# action choosen: 3
# next_state: (5, 5)
# q_value updated: 31.12998907367032
# Episode: 91000
# action choosen: 6
# next_state: (8, 3)
# q_value updated: 24.034385369821113
# Episode: 91100
# action choosen: 5
# next_state: (4, 10)
# q_value updated: 30.78587134806188
# Episode: 91200
# action choosen: 3
# next_state: (5, 8)
# q_value updated: 16.18170571144194
# Episode: 91300
# action choosen: 4
# next_state: (13, 10)
# q_value updated: 23.81556317565021
# Episode: 91400
# action choosen: 3
# next_state: (8, 8)
# q_value updated: 24.249109651667048
# Episode: 91500
# action choosen: 13
# next_state: (5, 11)
# q_value updated: 22.791965145002763
# Episode: 91600
# action choosen: 6
# next_state: (5, 10)
# q_value updated: 22.45452578582787
# Episode: 91700
# action choosen: 2
# next_state: (5, 10)
# q_value updated: 24.14911571435817
# Episode: 91800
# action choosen: 14
# next_state: (6, 6)
# q_value updated: 19.803723649604176
# Episode: 91900
# action choosen: 1
# next_state: (12, 6)
# q_value updated: 36.8153932042012
# Episode: 92000
# action choosen: 3
# next_state: (5, 10)
# q_value updated: 40.10084404834937
# Episode: 92100
# action choosen: 11
# next_state: (6, 6)
# q_value updated: 21.24689606966931
# Episode: 92200
# action choosen: 3
# next_state: (1, 3)
# q_value updated: 20.14944948264914
# Episode: 92300
# action choosen: 8
# next_state: (5, 11)
# q_value updated: 26.933429341458883
# Episode: 92400
# action choosen: 6
# next_state: (13, 11)
# q_value updated: 24.089485466161012
# Episode: 92500
# action choosen: 6
# next_state: (12, 11)
# q_value updated: 18.454652514087
# Episode: 92600
# action choosen: 5
# next_state: (7, 12)
# q_value updated: 24.928583889354336
# Episode: 92700
# action choosen: 13
# next_state: (6, 6)
# q_value updated: 23.214660074868902
# Episode: 92800
# action choosen: 6
# next_state: (6, 5)
# q_value updated: 19.650362534554418
# Episode: 92900
# action choosen: 5
# next_state: (1, 11)
# q_value updated: 21.43429657352978
# Episode: 93000
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 23.976865298763933
# Episode: 93100
# action choosen: 2
# next_state: (14, 3)
# q_value updated: 18.59478415897438
# Episode: 93200
# action choosen: 12
# next_state: (14, 3)
# q_value updated: 17.07764004156731
# Episode: 93300
# action choosen: 4
# next_state: (5, 10)
# q_value updated: 25.490088652182514
# Episode: 93400
# action choosen: 13
# next_state: (7, 3)
# q_value updated: 29.505012053099346
# Episode: 93500
# action choosen: 7
# next_state: (3, 7)
# q_value updated: 18.85748162798464
# Episode: 93600
# action choosen: 6
# next_state: (8, 8)
# q_value updated: 13.313283137254714
# Episode: 93700
# action choosen: 4
# next_state: (3, 3)
# q_value updated: 16.788930969340143
# Episode: 93800
# action choosen: 7
# next_state: (3, 3)
# q_value updated: 22.675289933141304
# Episode: 93900
# action choosen: 6
# next_state: (5, 5)
# q_value updated: 26.711135651755676
# Episode: 94000
# action choosen: 7
# next_state: (3, 4)
# q_value updated: 20.750537523125097
# Episode: 94100
# action choosen: 2
# next_state: (8, 8)
# q_value updated: 32.73605606070497
# Episode: 94200
# action choosen: 13
# next_state: (13, 1)
# q_value updated: 22.1757512003729
# Episode: 94300
# action choosen: 2
# next_state: (4, 10)
# q_value updated: 22.67377108492955
# Episode: 94400
# action choosen: 8
# next_state: (2, 2)
# q_value updated: 20.010194130948403
# Episode: 94500
# action choosen: 10
# next_state: (6, 2)
# q_value updated: 16.725663671950958
# Episode: 94600
# action choosen: 5
# next_state: (3, 6)
# q_value updated: 23.680540969284593
# Episode: 94700
# action choosen: 8
# next_state: (5, 10)
# q_value updated: 23.417726656881065
# Episode: 94800
# action choosen: 6
# next_state: (8, 8)
# q_value updated: 23.349036104521083
# Episode: 94900
# action choosen: 14
# next_state: (5, 13)
# q_value updated: 36.099298341009195
# Episode: 95000
# action choosen: 6
# next_state: (4, 11)
# q_value updated: 22.702926276642916
# Episode: 95100
# action choosen: 5
# next_state: (11, 10)
# q_value updated: 19.251046963667335
# Episode: 95200
# action choosen: 10
# next_state: (5, 8)
# q_value updated: 17.041489034983123
# Episode: 95300
# action choosen: 3
# next_state: (6, 14)
# q_value updated: 31.719259070664492
# Episode: 95400
# action choosen: 13
# next_state: (2, 1)
# q_value updated: 15.541812856885905
# Episode: 95500
# action choosen: 8
# next_state: (13, 6)
# q_value updated: 23.912769422344095
# Episode: 95600
# action choosen: 2
# next_state: (8, 7)
# q_value updated: 14.518892572613952
# Episode: 95700
# action choosen: 6
# next_state: (2, 14)
# q_value updated: 18.385957020649784
# Episode: 95800
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 38.149550366823206
# Episode: 95900
# action choosen: 6
# next_state: (14, 7)
# q_value updated: 31.239077487797395
# Episode: 96000
# action choosen: 3
# next_state: (5, 6)
# q_value updated: 29.38225777296427
# Episode: 96100
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 23.871399896274216
# Episode: 96200
# action choosen: 5
# next_state: (6, 6)
# q_value updated: 30.007736704446486
# Episode: 96300
# action choosen: 6
# next_state: (5, 10)
# q_value updated: 39.58703219555832
# Episode: 96400
# action choosen: 2
# next_state: (14, 3)
# q_value updated: 26.755038531785143
# Episode: 96500
# action choosen: 4
# next_state: (6, 6)
# q_value updated: 16.028188576646322
# Episode: 96600
# action choosen: 7
# next_state: (5, 5)
# q_value updated: 22.03857700505558
# Episode: 96700
# action choosen: 3
# next_state: (3, 10)
# q_value updated: 21.511242210703905
# Episode: 96800
# action choosen: 12
# next_state: (5, 10)
# q_value updated: 21.658859336134647
# Episode: 96900
# action choosen: 7
# next_state: (6, 14)
# q_value updated: 18.553449070391352
# Episode: 97000
# action choosen: 9
# next_state: (7, 3)
# q_value updated: 17.833902224461973
# Episode: 97100
# action choosen: 9
# next_state: (3, 10)
# q_value updated: 19.02092829518852
# Episode: 97200
# action choosen: 6
# next_state: (11, 6)
# q_value updated: 31.278592314523813
# Episode: 97300
# action choosen: 6
# next_state: (5, 2)
# q_value updated: 29.524626382054258
# Episode: 97400
# action choosen: 6
# next_state: (10, 4)
# q_value updated: 29.113545776175073
# Episode: 97500
# action choosen: 7
# next_state: (10, 8)
# q_value updated: 27.355879330811952
# Episode: 97600
# action choosen: 4
# next_state: (5, 2)
# q_value updated: 19.423790522355986
# Episode: 97700
# action choosen: 13
# next_state: (3, 5)
# q_value updated: 18.35906544346745
# Episode: 97800
# action choosen: 6
# next_state: (10, 2)
# q_value updated: 30.997200859698708
# Episode: 97900
# action choosen: 8
# next_state: (3, 3)
# q_value updated: 24.8494501260692
# Episode: 98000
# action choosen: 3
# next_state: (5, 13)
# q_value updated: 30.499394229492008
# Episode: 98100
# action choosen: 7
# next_state: (7, 10)
# q_value updated: 15.803183927652823
# Episode: 98200
# action choosen: 8
# next_state: (5, 10)
# q_value updated: 26.87528794882376
# Episode: 98300
# action choosen: 8
# next_state: (13, 11)
# q_value updated: 24.091416991442802
# Episode: 98400
# action choosen: 13
# next_state: (5, 2)
# q_value updated: 25.809767682175004
# Episode: 98500
# action choosen: 7
# next_state: (1, 8)
# q_value updated: 14.27342094805006
# Episode: 98600
# action choosen: 3
# next_state: (2, 10)
# q_value updated: 23.456885170054928
# Episode: 98700
# action choosen: 13
# next_state: (2, 10)
# q_value updated: 25.67262068925976
# Episode: 98800
# action choosen: 7
# next_state: (5, 8)
# q_value updated: 19.88210989273948
# Episode: 98900
# action choosen: 13
# next_state: (8, 7)
# q_value updated: 25.98428672915319
# Episode: 99000
# action choosen: 2
# next_state: (2, 2)
# q_value updated: 23.85879358892685
# Episode: 99100
# action choosen: 5
# next_state: (8, 3)
# q_value updated: 18.522467993675193
# Episode: 99200
# action choosen: 4
# next_state: (7, 11)
# q_value updated: 24.378606224908218
# Episode: 99300
# action choosen: 5
# next_state: (7, 12)
# q_value updated: 37.42503474410371
# Episode: 99400
# action choosen: 1
# next_state: (5, 10)
# q_value updated: 19.907424897089477
# Episode: 99500
# action choosen: 1
# next_state: (6, 11)
# q_value updated: 22.07039971726769
# Episode: 99600
# action choosen: 7
# next_state: (8, 10)
# q_value updated: 15.250817117725262
# Episode: 99700
# action choosen: 12
# next_state: (3, 7)
# q_value updated: 16.584128842164482
# Episode: 99800
# action choosen: 5
# next_state: (6, 3)
# q_value updated: 22.919979012920606
# Episode: 99900
# action choosen: 5
# next_state: (4, 3)
# q_value updated: 26.250923597243915
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 87.83

# %% [markdown]
# ## Q_table visualization

# %%
#save_q_table(env_aa,table_name='q_table_aa', dir_name=directory_name)

# %% [markdown]
# # Action-per-Emotion Model

# %% [markdown]
# ### Load P action per emotion matrix

# %%
with open('P_action_per_emotion.json') as f:
    P_ae = json.load(f)

print(P_ae)

# convert keys into numbers
new_P = {}
for k in P_ae.keys():
    new_P[int(k)]=P_ae[k]

P_ae = new_P
print(P_ae)
# Out:
# {'1': [[0.15384615384615385, 3, 6], [0.07692307692307693, 5, 4], [0.07692307692307693, 6, 4], [0.07692307692307693, 7, 0], [0.3076923076923077, 8, 7], [0.3076923076923077, 10, 2]], '2': [[0.06666666666666667, 2, 2], [0.1, 3, 4], [0.06666666666666667, 5, 1], [0.2, 6, 34], [0.03333333333333333, 7, 0], [0.1, 8, 11], [0.16666666666666666, 10, 19], [0.13333333333333333, 11, 3], [0.06666666666666667, 12, -2], [0.03333333333333333, 13, 6], [0.03333333333333333, 14, 3]], '3': [[0.019230769230769232, 1, -1], [0.07692307692307693, 2, 6], [0.07692307692307693, 3, 2], [0.038461538461538464, 4, 4], [0.07692307692307693, 5, 1], [0.17307692307692307, 6, 8], [0.07692307692307693, 7, 6], [0.038461538461538464, 8, 3], [0.23076923076923078, 10, 6], [0.11538461538461539, 11, 6], [0.019230769230769232, 12, 4], [0.057692307692307696, 14, 3]], '4': [[0.041666666666666664, 2, 3], [0.08333333333333333, 3, 1], [0.08333333333333333, 4, 0], [0.041666666666666664, 5, -1], [0.16666666666666666, 6, 0], [0.125, 8, -2], [0.25, 10, -5], [0.041666666666666664, 11, -1], [0.08333333333333333, 12, -2], [0.08333333333333333, 13, 2]], '5': [[0.02857142857142857, 1, 1], [0.02857142857142857, 2, 4], [0.14285714285714285, 3, 7], [0.02857142857142857, 4, 0], [0.05714285714285714, 5, 12], [0.08571428571428572, 6, 2], [0.05714285714285714, 7, 0], [0.11428571428571428, 8, 7], [0.3142857142857143, 10, 23], [0.11428571428571428, 11, 8], [0.02857142857142857, 14, 2]]}
# {1: [[0.15384615384615385, 3, 6], [0.07692307692307693, 5, 4], [0.07692307692307693, 6, 4], [0.07692307692307693, 7, 0], [0.3076923076923077, 8, 7], [0.3076923076923077, 10, 2]], 2: [[0.06666666666666667, 2, 2], [0.1, 3, 4], [0.06666666666666667, 5, 1], [0.2, 6, 34], [0.03333333333333333, 7, 0], [0.1, 8, 11], [0.16666666666666666, 10, 19], [0.13333333333333333, 11, 3], [0.06666666666666667, 12, -2], [0.03333333333333333, 13, 6], [0.03333333333333333, 14, 3]], 3: [[0.019230769230769232, 1, -1], [0.07692307692307693, 2, 6], [0.07692307692307693, 3, 2], [0.038461538461538464, 4, 4], [0.07692307692307693, 5, 1], [0.17307692307692307, 6, 8], [0.07692307692307693, 7, 6], [0.038461538461538464, 8, 3], [0.23076923076923078, 10, 6], [0.11538461538461539, 11, 6], [0.019230769230769232, 12, 4], [0.057692307692307696, 14, 3]], 4: [[0.041666666666666664, 2, 3], [0.08333333333333333, 3, 1], [0.08333333333333333, 4, 0], [0.041666666666666664, 5, -1], [0.16666666666666666, 6, 0], [0.125, 8, -2], [0.25, 10, -5], [0.041666666666666664, 11, -1], [0.08333333333333333, 12, -2], [0.08333333333333333, 13, 2]], 5: [[0.02857142857142857, 1, 1], [0.02857142857142857, 2, 4], [0.14285714285714285, 3, 7], [0.02857142857142857, 4, 0], [0.05714285714285714, 5, 12], [0.08571428571428572, 6, 2], [0.05714285714285714, 7, 0], [0.11428571428571428, 8, 7], [0.3142857142857143, 10, 23], [0.11428571428571428, 11, 8], [0.02857142857142857, 14, 2]]}

# %% [markdown]
# ## Double-Q-Learning off-policy Training

# %%
'''
bst_alpha = 0.06
bst_gamma = 0.6
bst_td = 14

gamma = bst_gamma
epsilon = 0.1
min_difference = 0.000001 # 10^-7
td_step = bst_td
alpha = bst_alpha

hyperparameters = []


#a = [i / 100.0 for i in range(0, 31, 3)]
a = [i / 100.0 for i in range(0, 61, 10)]
td = range(0,16,1)

for idx,elem in enumerate(a):
    if train:
        hp = {  "gamma" : gamma,
                "alpha": elem,
                "td_step": td_step,
                "epsilon_min": epsilon}
        hyperparameters.append(hp)
        env = ImprobotEnv(actor_space=ACTIONS,robot_space=EMOTIONS,sketch_lenght=15,env_matrix=P_ae, P0=P0)
        double_q_learning_train(alpha=elem,gamma=gamma,epsilon=epsilon, TD_step=td_step,min_q_diff=min_difference,env=env)
        history["ae_history"].append(policy_eval(env))

max_idx = np.argmax(history["ae_history"])
avg_reward_ae = history["ae_history"][max_idx]
directory_name = model_name + "bst_ae" + "_hp_gm_" + str(hyperparameters[max_idx]["gamma"]) + "_alph_" + str(hyperparameters[max_idx]["alpha"]) + "_td_" + str(hyperparameters[max_idx]["td_step"]) + "_eps_" + str(hyperparameters[max_idx]["epsilon_min"])
write_csv(directory_name, 0, avg_reward_ae)
'''
# Out:
# '\nbst_alpha = 0.06\nbst_gamma = 0.6\nbst_td = 14\n\ngamma = bst_gamma\nepsilon = 0.1\nmin_difference = 0.000001 # 10^-7\ntd_step = bst_td\nalpha = bst_alpha\n\nhyperparameters = []\n\n\n#a = [i / 100.0 for i in range(0, 31, 3)]\na = [i / 100.0 for i in range(0, 61, 10)]\ntd = range(0,16,1)\n\nfor idx,elem in enumerate(a):\n    if train:\n        hp = {  "gamma" : gamma,\n                "alpha": elem,\n                "td_step": td_step,\n                "epsilon_min": epsilon}\n        hyperparameters.append(hp)\n        env = ImprobotEnv(actor_space=ACTIONS,robot_space=EMOTIONS,sketch_lenght=15,env_matrix=P_ae, P0=P0)\n        double_q_learning_train(alpha=elem,gamma=gamma,epsilon=epsilon, TD_step=td_step,min_q_diff=min_difference,env=env)\n        history["ae_history"].append(policy_eval(env))\n\nmax_idx = np.argmax(history["ae_history"])\navg_reward_ae = history["ae_history"][max_idx]\ndirectory_name = model_name + "bst_ae" + "_hp_gm_" + str(hyperparameters[max_idx]["gamma"]) + "_alph_" + str(hyperparameters[max_idx]["alpha"]) + "_td_" + str(hyperparameters[max_idx]["td_step"]) + "_eps_" + str(hyperparameters[max_idx]["epsilon_min"])\nwrite_csv(directory_name, 0, avg_reward_ae)\n'

# %% [markdown]
# ## Q_table visualization

# %%
#save_q_table(env_ae,table_name='q_table_ae', dir_name=directory_name)

# %%
print(history)
# Out:
# {'aa_history': [4.16, 83.3, 88.31, 78.87, 77.33, 89.62, 87.83], 'ae_history': []}
