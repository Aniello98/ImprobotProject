# %%
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Tuple
import copy
import numpy as np
import random, json, csv, os
import matplotlib.pyplot as plt

# %%
train = True
directory_name = 'DOUBLE_Q_Learning_le0.1_gm_0.4_alp_0.06_TD0'

# %%
ACTIONS = [ "none",
            "attack",
            "scolding",
            "intimidate",
            "grudge",
            "sharing_happiness",
            "happy_person",
            "satisfaction",
            "sharing_fear",
            "running_away",
            "sharing_sadness",
            "disappointment",
            "surprise",
            "disbelief",
            "astonishment"
            ]

            
            
EMOTIONS = ["none",
            "fear",
            "joy",
            "surprise",
            "sadness",
            "anger"
            ]

EMOTION_PER_ACTION = { "none": "none",
            "attack" : "anger",
            "scolding": "anger",
            "intimidate": "anger",
            "grudge": "anger",
            "sharing_happiness": "joy",
            "happy_person": "joy",
            "satisfaction": "joy",
            "sharing_fear": "fear",
            "running_away": "fear",
            "sharing_sadness": "sadness",
            "disappointment": "sadness",
            "surprise": "surprise",
            "disbelief": "surprise",
            "astonishment": "surprise"
}

# %%
SCENIC_ACTION_SIZE = len(ACTIONS)
EMOTIONAL_REACTION_SIZE = len(EMOTIONS)

MAXIMUM_SKETCH_LENGTH = 15

# %%
# returns the code number of an action given by name
def parse_action(action):
    return ACTIONS.index(action)

#returns the action associated to a code
def unparse_action(code):
    return ACTIONS[code]

# returns the code number of an action given by name
def parse_emotion(action):
    return EMOTIONS.index(action)

#returns the action associated to a code
def unparse_emotion(code):
    return EMOTIONS[code]

def convert_action_into_emo(action):
    return EMOTION_PER_ACTION[action]

# %%
class ImprobotEnv(Env):

    def __init__(self, actor_space, robot_space, sketch_lenght, env_matrix, P0):

        self.action_space = Discrete(len(robot_space))
        # environment conditions space
        self.observation_space = Tuple((Discrete(len(robot_space)), Discrete(len(actor_space)))) # (robot reaction, actor action)
        self.state = () # (last robot reaction, last actor action)
        self.initial_action_P = P0
        self.sketch_length = sketch_lenght
        self.counter = 0
        self.P = env_matrix # {action: [probability, actor_action, reward]}
        self.q_table_1 = np.zeros([self.observation_space[0].n, self.observation_space[1].n, self.action_space.n])
        self.q_table_2 = np.zeros([self.observation_space[0].n, self.observation_space[1].n, self.action_space.n])
    
    def render(self):
        print(f"Last actor scenic action: {self.state[1]}")
        print(f"Last robot reaction: {self.state[0]}")

    def step(self, action):
        possible_next_states = self.P[action]
        probabilities = []

        for elem in possible_next_states:
            probabilities.append(elem[0])

        #print(probabilities)
        #print(possible_next_states)
        new_observation_idx = np.random.choice(len(possible_next_states), p=probabilities)
        
        new_observation = possible_next_states[new_observation_idx]
        # update state
        new_reaction = action
        new_actor_action = new_observation[1]
        self.state = tuple([new_reaction, new_actor_action])
        reward = new_observation[2]

        #self.counter += 1

        if self.counter == self.sketch_length:
            done = True
        else:
            done = False

        return self.state, reward, done

    def reset(self):
        actor_action = np.random.choice(SCENIC_ACTION_SIZE,p=self.initial_action_P)
        #print(f"initial action: {actor_action}")
        self.state = (0, actor_action) # (none, none)
        self.counter = 0
        return self.state

# %%
# initial action probability distribution
equal_prob = 1/(SCENIC_ACTION_SIZE-1)
P0 = np.zeros(15)
P0[1:] = np.full(14, equal_prob)

# %% [markdown]
# # DOUBLE-Q-Learning

# %%
def policy_eval(env):
    total_epochs = 0
    total_rewards = 0
    episodes = 100

    for _ in range(episodes):
        state = env.reset()
        epochs, reward = 0, 0
        
        done = False
        
        while not done:
            action_values = env.q_table_1[state[0]][state[1]][1:] + env.q_table_2[state[0]][state[1]][1:]
            action = np.argmax(action_values) + 1 # Exploit learned values
            state, reward, _ = env.step(action)

            total_rewards += reward

            env.counter += 1

            if env.counter == env.sketch_length:
                done = True
            else:
                done = False

            epochs += 1

        total_epochs += epochs

    print(f"Results after {episodes} episodes:")
    print(f"Average timesteps per episode: {total_epochs / episodes}")
    print(f"Average rewards per episode: {total_rewards / episodes}")
    return total_rewards / episodes

# %%
def double_q_learning_train(alpha, gamma, epsilon, TD_step, min_q_diff, env):
    # mask in order to non choose action none during the training
    mask = np.ones(env.observation_space[0].n, dtype=np.int8)
    mask[0] = 0

    epochs_number = 200000
    avg_rwd_history = []
    epochs_vect = []
    
    for i in range(1, epochs_number):
        q_old_1 = copy.deepcopy(env.q_table_1)
        q_old_2 = copy.deepcopy(env.q_table_2)
        state = env.reset()

        epochs, reward = 0, 0
        done = False
        
        epsilon = -0.9/50000 * epochs_number + 1 if epochs_number < 50000 else 0.1
        #epsilon = 1 if epochs_number<100000 else 0

        while not done:

            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample(mask=mask) # Explore action space
                #print(f"random action: {action}")
            else:
                # choose action using q1+q2 value
                action_values = env.q_table_1[state[0]][state[1]][1:] + env.q_table_2[state[0]][state[1]][1:]
                action = np.argmax(action_values) + 1 # Exploit learned values
                #print(f"argmax action: {action}")

            '''
            initial_action = action
            states = [state]
            rewds = []
            gamma_arr = []
            for j in range(TD_step+1):
                if env.counter + j < env.sketch_length:
                    next_state, reward, _ = env.step(action)
                    states.append(next_state)
                    rewds.append(reward)
                    gamma_arr.append(gamma ** j)
                    
                    if random.uniform(0, 1) < epsilon:
                        action = env.action_space.sample(mask=mask)  # Explore action space
                    else:
                        # choose action using q1+q2 value
                        action_values = env.q_table_1[next_state[0]][next_state[1]][1:] + env.q_table_2[next_state[0]][next_state[1]][1:]
                        action = np.argmax(action_values) + 1  # Exploit learned values
                else:
                    break

            if env.counter + TD_step < env.sketch_length:
                next_state = states[-1]
                next_max_1 = np.max(env.q_table_1[next_state[0]][next_state[1]][1:])
                next_max_2 = np.max(env.q_table_2[next_state[0]][next_state[1]][1:])
                
                gamma_arr.append(gamma ** (TD_step+1))

                if random.uniform(0, 1) < 0.5:
                    old_value = env.q_table_1[state[0]][state[1]][initial_action]
                    rewds.append(next_max_2)
                    G = np.multiply(rewds,gamma_arr)
                    new_value = (1 - alpha) * old_value + np.sum(alpha * np.array(G))
                    env.q_table_1[state[0]][state[1]][action] = new_value
                else:
                    old_value = env.q_table_2[state[0]][state[1]][initial_action]
                    rewds.append(next_max_1)
                    G = np.multiply(rewds,gamma_arr)
                    new_value = (1 - alpha) * old_value + np.sum(alpha * np.array(G))
                    env.q_table_2[state[0]][state[1]][action] = new_value
            '''

            
            next_state, reward, done = env.step(action)

            # update q1 or q2 table with probbility 0.5
            if random.uniform(0,1) < 0.5:
                old_value = env.q_table_1[state[0]][state[1]][action]
                new_value = (1 - alpha) * old_value + alpha * (reward + gamma * env.q_table_2[next_state[0]][next_state[1]][np.argmax(env.q_table_1[next_state[0]][next_state[1]][1:]) + 1])
                env.q_table_1[state[0]][state[1]][action] = new_value
            else:
                old_value = env.q_table_2[state[0]][state[1]][action]
                new_value = (1 - alpha) * old_value + alpha * (reward + gamma * env.q_table_1[next_state[0]][next_state[1]][np.argmax(env.q_table_2[next_state[0]][next_state[1]][1:]) + 1])
                env.q_table_2[state[0]][state[1]][action] = new_value
            
            state = next_state
            epochs += 1

            env.counter += 1

            if env.counter == env.sketch_length:
                done = True
            else:
                done = False

            #print(f"Episode: {i}")
            #print(f"Epoch: {epochs}")
            #print(f"actual_state: {env.state}")
            #print(f"action choosen: {action}")
            #print(f"next_state: {next_state}")
            #print(f"q_value updated: {env.q_table[state[0]][state[1]][action]}")

        if i % 100 == 0:
            print(f"Episode: {i}")
            print(f"action choosen: {action}")
            print(f"next_state: {next_state}")
            print(f"q_value updated: {env.q_table_1[state[0]][state[1]][action]}")
            avg_rwd_history.append(policy_eval(env))
            epochs_vect.append(i)
    plt.plot(epochs_vect,avg_rwd_history)
    plt.xlabel("Epochs Number")
    plt.ylabel("Average Reward")
    plt.show()



print("training finished.\n")
# Out:
# training finished.

# %%
def save_q_table(env,table_name, dir_name):
    reshaped_Q_1 = env.q_table_1.reshape((env.q_table_1.shape[0]*env.q_table_1.shape[1]),env.q_table_1.shape[2])
    reshaped_Q_2 = env.q_table_2.reshape((env.q_table_2.shape[0]*env.q_table_2.shape[1]),env.q_table_2.shape[2])
    reshaped_Q = np.add(reshaped_Q_1,reshaped_Q_2)
    header = ["S(robot reaction, actor action)", "none", "attack", "scolding", "intimidate", "grudge", "sharing_happiness",
          "happy_person", "satisfaction", "sharing_fear", "running_away", "sharing_sadness", "disappointment",
          "surprise", "disbelief", "astonishment"] if env.observation_space[0].n == 15 else ["S(robot reaction, actor action)", "none", "fear", "joy", "surprise", "sadness", "anger"]
    reaction_unparser = unparse_action if env.observation_space[0].n == 15 else unparse_emotion
    
    data = []
    
    for i in range(reshaped_Q.shape[0]):
        if int(i/env.observation_space[1].n) == 0:
            reaction = reaction_unparser(0)
            row = [(reaction,unparse_action(i))]
        else:
            reaction = int(i/env.observation_space[1].n)
            #print(f"here is the reaction: {reaction}")
            #print(f"here is the i: {i}")
            reaction = reaction_unparser(reaction)
            row = [(reaction, unparse_action((i%env.observation_space[1].n)))]
        row.extend(reshaped_Q[i])
        data.append(row)

    # Scrittura del file CSV
    if not os.path.exists('trials/' + dir_name):
        os.makedirs('trials/' + dir_name)

    with open('trials/' + dir_name + '/' + table_name + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(data)

# %% [markdown]
# # Action-per-Action learning Test

# %% [markdown]
# ### Load P action per action matrix

# %%
with open('P_action_per_action.json') as f:
    P_aa = json.load(f)

print(P_aa)

# convert keys into numbers
new_P = {}
for k in P_aa.keys():
    new_P[int(k)]=P_aa[k]

P_aa = new_P
print(P_aa)
# Out:
# {'1': [[0.125, 3, 2], [0.125, 5, 0], [0.125, 6, -4], [0.125, 7, 0], [0.125, 8, 4], [0.25, 10, -1], [0.125, 11, 3]], '2': [[0.14285714285714285, 1, 1], [0.14285714285714285, 2, 4], [0.14285714285714285, 8, 0], [0.2857142857142857, 10, 13], [0.14285714285714285, 11, 4], [0.14285714285714285, 14, 2]], '3': [[0.25, 3, 5], [0.08333333333333333, 4, 0], [0.08333333333333333, 5, 12], [0.16666666666666666, 6, 6], [0.08333333333333333, 7, 0], [0.08333333333333333, 8, 2], [0.25, 10, 9]], '4': [[0.125, 3, 0], [0.125, 8, 1], [0.5, 10, 2], [0.25, 11, 1]], '5': [[0.1, 2, 1], [0.1, 5, 1], [0.2, 6, 8], [0.2, 8, 11], [0.2, 10, 15], [0.1, 11, 2], [0.1, 13, 6]], '6': [[0.08333333333333333, 2, 1], [0.08333333333333333, 3, -2], [0.08333333333333333, 5, 0], [0.3333333333333333, 6, 26], [0.08333333333333333, 8, 0], [0.16666666666666666, 11, -2], [0.08333333333333333, 12, -1], [0.08333333333333333, 14, 3]], '7': [[0.25, 3, 6], [0.125, 7, 0], [0.375, 10, 4], [0.125, 11, 3], [0.125, 12, -1]], '8': [[0.2, 3, 6], [0.1, 5, 4], [0.1, 7, 0], [0.4, 8, 7], [0.2, 10, 5]], '9': [[0.3333333333333333, 6, 4], [0.6666666666666666, 10, -3]], '10': [[0.08333333333333333, 2, 3], [0.16666666666666666, 3, 1], [0.08333333333333333, 4, 1], [0.08333333333333333, 6, 3], [0.16666666666666666, 8, -3], [0.16666666666666666, 10, 1], [0.16666666666666666, 12, -2], [0.08333333333333333, 13, 2]], '11': [[0.08333333333333333, 4, -1], [0.08333333333333333, 5, -1], [0.25, 6, -3], [0.08333333333333333, 8, 1], [0.3333333333333333, 10, -6], [0.08333333333333333, 11, -1], [0.08333333333333333, 13, 0]], '12': [[0.05263157894736842, 4, 3], [0.05263157894736842, 5, 0], [0.2631578947368421, 6, 9], [0.05263157894736842, 7, 1], [0.10526315789473684, 8, 3], [0.2631578947368421, 10, -1], [0.10526315789473684, 11, -2], [0.05263157894736842, 12, 4], [0.05263157894736842, 14, 3]], '13': [[0.1111111111111111, 1, -1], [0.1111111111111111, 2, 0], [0.1111111111111111, 5, 0], [0.1111111111111111, 6, 0], [0.3333333333333333, 10, 5], [0.2222222222222222, 11, 8]], '14': [[0.125, 2, 6], [0.16666666666666666, 3, 2], [0.041666666666666664, 4, 1], [0.08333333333333333, 5, 1], [0.125, 6, -1], [0.125, 7, 5], [0.16666666666666666, 10, 2], [0.08333333333333333, 11, 0], [0.08333333333333333, 14, 0]]}
# {1: [[0.125, 3, 2], [0.125, 5, 0], [0.125, 6, -4], [0.125, 7, 0], [0.125, 8, 4], [0.25, 10, -1], [0.125, 11, 3]], 2: [[0.14285714285714285, 1, 1], [0.14285714285714285, 2, 4], [0.14285714285714285, 8, 0], [0.2857142857142857, 10, 13], [0.14285714285714285, 11, 4], [0.14285714285714285, 14, 2]], 3: [[0.25, 3, 5], [0.08333333333333333, 4, 0], [0.08333333333333333, 5, 12], [0.16666666666666666, 6, 6], [0.08333333333333333, 7, 0], [0.08333333333333333, 8, 2], [0.25, 10, 9]], 4: [[0.125, 3, 0], [0.125, 8, 1], [0.5, 10, 2], [0.25, 11, 1]], 5: [[0.1, 2, 1], [0.1, 5, 1], [0.2, 6, 8], [0.2, 8, 11], [0.2, 10, 15], [0.1, 11, 2], [0.1, 13, 6]], 6: [[0.08333333333333333, 2, 1], [0.08333333333333333, 3, -2], [0.08333333333333333, 5, 0], [0.3333333333333333, 6, 26], [0.08333333333333333, 8, 0], [0.16666666666666666, 11, -2], [0.08333333333333333, 12, -1], [0.08333333333333333, 14, 3]], 7: [[0.25, 3, 6], [0.125, 7, 0], [0.375, 10, 4], [0.125, 11, 3], [0.125, 12, -1]], 8: [[0.2, 3, 6], [0.1, 5, 4], [0.1, 7, 0], [0.4, 8, 7], [0.2, 10, 5]], 9: [[0.3333333333333333, 6, 4], [0.6666666666666666, 10, -3]], 10: [[0.08333333333333333, 2, 3], [0.16666666666666666, 3, 1], [0.08333333333333333, 4, 1], [0.08333333333333333, 6, 3], [0.16666666666666666, 8, -3], [0.16666666666666666, 10, 1], [0.16666666666666666, 12, -2], [0.08333333333333333, 13, 2]], 11: [[0.08333333333333333, 4, -1], [0.08333333333333333, 5, -1], [0.25, 6, -3], [0.08333333333333333, 8, 1], [0.3333333333333333, 10, -6], [0.08333333333333333, 11, -1], [0.08333333333333333, 13, 0]], 12: [[0.05263157894736842, 4, 3], [0.05263157894736842, 5, 0], [0.2631578947368421, 6, 9], [0.05263157894736842, 7, 1], [0.10526315789473684, 8, 3], [0.2631578947368421, 10, -1], [0.10526315789473684, 11, -2], [0.05263157894736842, 12, 4], [0.05263157894736842, 14, 3]], 13: [[0.1111111111111111, 1, -1], [0.1111111111111111, 2, 0], [0.1111111111111111, 5, 0], [0.1111111111111111, 6, 0], [0.3333333333333333, 10, 5], [0.2222222222222222, 11, 8]], 14: [[0.125, 2, 6], [0.16666666666666666, 3, 2], [0.041666666666666664, 4, 1], [0.08333333333333333, 5, 1], [0.125, 6, -1], [0.125, 7, 5], [0.16666666666666666, 10, 2], [0.08333333333333333, 11, 0], [0.08333333333333333, 14, 0]]}

# %% [markdown]
# ### Create action-per-action environment

# %%
env_aa = ImprobotEnv(actor_space=ACTIONS,robot_space=ACTIONS,sketch_lenght=15,env_matrix=P_aa, P0=P0)

# %% [markdown]
# ## Q-Learning off-policy TD(1) Training

# %%
# Hyperparameters
alpha = 0.06
gamma = 0.4
epsilon = 0.1
min_difference = 0.000001 # 10^-7
td_step = 0

if train:
    double_q_learning_train(alpha=alpha,gamma=gamma,epsilon=epsilon, TD_step=td_step,min_q_diff=min_difference,env=env_aa)
# Out:
# Episode: 100
# action choosen: 7
# next_state: (7, 10)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.8
# Episode: 200
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 8.306730223181528
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 71.51
# Episode: 300
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 8.573433412712644
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 71.28
# Episode: 400
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 9.694348016377711
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 68.71
# Episode: 500
# action choosen: 7
# next_state: (7, 7)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 71.22
# Episode: 600
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 7.496062762317998
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 71.15
# Episode: 700
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 7.7040722335368885
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 70.22
# Episode: 800
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 75.85
# Episode: 900
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 7.473502849879066
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 70.38
# Episode: 1000
# action choosen: 7
# next_state: (7, 11)
# q_value updated: 0.09634923961606341
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.86
# Episode: 1100
# action choosen: 3
# next_state: (3, 10)
# q_value updated: 1.6137765706044167
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 72.2
# Episode: 1200
# action choosen: 2
# next_state: (2, 14)
# q_value updated: 8.666289392164714
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 74.8
# Episode: 1300
# action choosen: 2
# next_state: (2, 2)
# q_value updated: 8.55318082680918
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.07
# Episode: 1400
# action choosen: 7
# next_state: (7, 10)
# q_value updated: 0.473674078942871
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.63
# Episode: 1500
# action choosen: 2
# next_state: (2, 1)
# q_value updated: 6.669845439660185
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 70.07
# Episode: 1600
# action choosen: 2
# next_state: (2, 2)
# q_value updated: 8.21533740780849
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 74.07
# Episode: 1700
# action choosen: 2
# next_state: (2, 1)
# q_value updated: 7.879500556373746
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 77.26
# Episode: 1800
# action choosen: 8
# next_state: (8, 5)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.11
# Episode: 1900
# action choosen: 7
# next_state: (7, 11)
# q_value updated: 0.09634923961606341
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.73
# Episode: 2000
# action choosen: 7
# next_state: (7, 3)
# q_value updated: 1.6763648377860139
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 78.7
# Episode: 2100
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 7.17781584332634
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 79.33
# Episode: 2200
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 7.341277948856327
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 82.32
# Episode: 2300
# action choosen: 6
# next_state: (6, 11)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 80.11
# Episode: 2400
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 0.2090783742702213
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 77.48
# Episode: 2500
# action choosen: 7
# next_state: (7, 10)
# q_value updated: 2.4694055858385133
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 79.83
# Episode: 2600
# action choosen: 7
# next_state: (7, 7)
# q_value updated: 0.41992466581721993
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 79.05
# Episode: 2700
# action choosen: 2
# next_state: (2, 1)
# q_value updated: 9.258935705279715
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 81.06
# Episode: 2800
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 6.424310069796299
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 75.48
# Episode: 2900
# action choosen: 3
# next_state: (3, 10)
# q_value updated: 2.314909810792558
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 77.33
# Episode: 3000
# action choosen: 7
# next_state: (7, 11)
# q_value updated: 1.5695860433450677
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 81.7
# Episode: 3100
# action choosen: 9
# next_state: (9, 10)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 78.2
# Episode: 3200
# action choosen: 1
# next_state: (1, 10)
# q_value updated: -0.2906068923309358
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 75.56
# Episode: 3300
# action choosen: 1
# next_state: (1, 11)
# q_value updated: -0.03475544878080006
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 81.13
# Episode: 3400
# action choosen: 6
# next_state: (6, 6)
# q_value updated: 2.0700593882686156
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 79.65
# Episode: 3500
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 7.967177071684862
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 76.08
# Episode: 3600
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 8.434123037086563
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 73.12
# Episode: 3700
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 0.2611251278581027
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 75.74
# Episode: 3800
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 0.2611251278581027
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 75.63
# Episode: 3900
# action choosen: 3
# next_state: (3, 4)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode:
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 122.23

# %% [markdown]
# ## Q_table visualization

# %%
save_q_table(env_aa,table_name='q_table_aa', dir_name=directory_name)

# %% [markdown]
# # Action-per-Emotion Model

# %% [markdown]
# ### Load P action per emotion matrix

# %%
with open('P_action_per_emotion.json') as f:
    P_ae = json.load(f)

print(P_ae)

# convert keys into numbers
new_P = {}
for k in P_ae.keys():
    new_P[int(k)]=P_ae[k]

P_ae = new_P
print(P_ae)
# Out:
# {'1': [[0.15384615384615385, 3, 6], [0.07692307692307693, 5, 4], [0.07692307692307693, 6, 4], [0.07692307692307693, 7, 0], [0.3076923076923077, 8, 7], [0.3076923076923077, 10, 2]], '2': [[0.06666666666666667, 2, 2], [0.1, 3, 4], [0.06666666666666667, 5, 1], [0.2, 6, 34], [0.03333333333333333, 7, 0], [0.1, 8, 11], [0.16666666666666666, 10, 19], [0.13333333333333333, 11, 3], [0.06666666666666667, 12, -2], [0.03333333333333333, 13, 6], [0.03333333333333333, 14, 3]], '3': [[0.019230769230769232, 1, -1], [0.07692307692307693, 2, 6], [0.07692307692307693, 3, 2], [0.038461538461538464, 4, 4], [0.07692307692307693, 5, 1], [0.17307692307692307, 6, 8], [0.07692307692307693, 7, 6], [0.038461538461538464, 8, 3], [0.23076923076923078, 10, 6], [0.11538461538461539, 11, 6], [0.019230769230769232, 12, 4], [0.057692307692307696, 14, 3]], '4': [[0.041666666666666664, 2, 3], [0.08333333333333333, 3, 1], [0.08333333333333333, 4, 0], [0.041666666666666664, 5, -1], [0.16666666666666666, 6, 0], [0.125, 8, -2], [0.25, 10, -5], [0.041666666666666664, 11, -1], [0.08333333333333333, 12, -2], [0.08333333333333333, 13, 2]], '5': [[0.02857142857142857, 1, 1], [0.02857142857142857, 2, 4], [0.14285714285714285, 3, 7], [0.02857142857142857, 4, 0], [0.05714285714285714, 5, 12], [0.08571428571428572, 6, 2], [0.05714285714285714, 7, 0], [0.11428571428571428, 8, 7], [0.3142857142857143, 10, 23], [0.11428571428571428, 11, 8], [0.02857142857142857, 14, 2]]}
# {1: [[0.15384615384615385, 3, 6], [0.07692307692307693, 5, 4], [0.07692307692307693, 6, 4], [0.07692307692307693, 7, 0], [0.3076923076923077, 8, 7], [0.3076923076923077, 10, 2]], 2: [[0.06666666666666667, 2, 2], [0.1, 3, 4], [0.06666666666666667, 5, 1], [0.2, 6, 34], [0.03333333333333333, 7, 0], [0.1, 8, 11], [0.16666666666666666, 10, 19], [0.13333333333333333, 11, 3], [0.06666666666666667, 12, -2], [0.03333333333333333, 13, 6], [0.03333333333333333, 14, 3]], 3: [[0.019230769230769232, 1, -1], [0.07692307692307693, 2, 6], [0.07692307692307693, 3, 2], [0.038461538461538464, 4, 4], [0.07692307692307693, 5, 1], [0.17307692307692307, 6, 8], [0.07692307692307693, 7, 6], [0.038461538461538464, 8, 3], [0.23076923076923078, 10, 6], [0.11538461538461539, 11, 6], [0.019230769230769232, 12, 4], [0.057692307692307696, 14, 3]], 4: [[0.041666666666666664, 2, 3], [0.08333333333333333, 3, 1], [0.08333333333333333, 4, 0], [0.041666666666666664, 5, -1], [0.16666666666666666, 6, 0], [0.125, 8, -2], [0.25, 10, -5], [0.041666666666666664, 11, -1], [0.08333333333333333, 12, -2], [0.08333333333333333, 13, 2]], 5: [[0.02857142857142857, 1, 1], [0.02857142857142857, 2, 4], [0.14285714285714285, 3, 7], [0.02857142857142857, 4, 0], [0.05714285714285714, 5, 12], [0.08571428571428572, 6, 2], [0.05714285714285714, 7, 0], [0.11428571428571428, 8, 7], [0.3142857142857143, 10, 23], [0.11428571428571428, 11, 8], [0.02857142857142857, 14, 2]]}

# %% [markdown]
# ### Create action-per-emotion environment

# %%
env_ae = ImprobotEnv(actor_space=ACTIONS,robot_space=EMOTIONS,sketch_lenght=15,env_matrix=P_ae, P0=P0)

# %% [markdown]
# ## Q-Learning off-policy TD(1) Training

# %%
# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
min_difference = 0.000001
td_step = 0

if train:
    double_q_learning_train(alpha=alpha,gamma=gamma,epsilon=epsilon, TD_step=td_step,min_q_diff=min_difference,env=env_ae)
# Out:
# Episode: 100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 11.566964641271488
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 87.36
# Episode: 200
# action choosen: 5
# next_state: (5, 11)
# q_value updated: 3.074767234249821
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 88.29
# Episode: 300
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 7.786498886607666
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 103.75
# Episode: 400
# action choosen: 5
# next_state: (5, 11)
# q_value updated: 5.539352700529267
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 103.05
# Episode: 500
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 13.230760001208708
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 106.01
# Episode: 600
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 10.716971658277092
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 102.98
# Episode: 700
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 106.5
# Episode: 800
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 21.657512447231408
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 103.28
# Episode: 900
# action choosen: 2
# next_state: (2, 11)
# q_value updated: 0.7171855247034645
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 113.08
# Episode: 1000
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 15.740055950763427
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 113.95
# Episode: 1100
# action choosen: 5
# next_state: (5, 2)
# q_value updated: 0.0
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 111.55
# Episode: 1200
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 16.3566728800429
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 116.31
# Episode: 1300
# action choosen: 1
# next_state: (1, 6)
# q_value updated: 15.913895841795645
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 120.26
# Episode: 1400
# action choosen: 2
# next_state: (2, 6)
# q_value updated: 4.467382603480558
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 126.04
# Episode: 1500
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 11.915777618626286
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 129.11
# Episode: 1600
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 17.2674494348874
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 116.82
# Episode: 1700
# action choosen: 2
# next_state: (2, 6)
# q_value updated: 12.717166507373008
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 117.63
# Episode: 1800
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 16.084031296105124
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 120.21
# Episode: 1900
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 15.148206149252012
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 126.02
# Episode: 2000
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 24.098904155465494
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 130.95
# Episode: 2100
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 16.975992382998548
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 134.13
# Episode: 2200
# action choosen: 1
# next_state: (1, 5)
# q_value updated: 18.284646289026462
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 127.37
# Episode: 2300
# action choosen: 1
# next_state: (1, 10)
# q_value updated: 15.688887276810124
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 130.37
# Episode: 2400
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 24.02653498263215
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 131.92
# Episode: 2500
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 25.554666461455998
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 140.09
# Episode: 2600
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 16.91735507817051
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 133.82
# Episode: 2700
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 18.330529757340422
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 129.65
# Episode: 2800
# action choosen: 2
# next_state: (2, 11)
# q_value updated: 10.73108205483537
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 134.06
# Episode: 2900
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 17.518036105504112
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 135.66
# Episode: 3000
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 23.845390354314482
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 133.87
# Episode: 3100
# action choosen: 2
# next_state: (2, 14)
# q_value updated: 6.316918879301818
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 130.11
# Episode: 3200
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 19.97435919546805
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 132.67
# Episode: 3300
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 19.97435919546805
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 132.93
# Episode: 3400
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 28.229811031648193
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 133.11
# Episode: 3500
# action choosen: 1
# next_state: (1, 3)
# q_value updated: 16.509942612170217
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 137.85
# Episode: 3600
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 26.045381700016822
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 133.18
# Episode: 3700
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 24.042665713894298
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 135.18
# Episode: 3800
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 23.534651983663856
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 140.73
# Episode: 3900
# action choosen: 5
# next_state: (5, 5)
# q_value updated: 17.780272011939623
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 135.66
# Episode: 4000
# action choosen: 5
# next_state: (5, 2)
# q_value updated: 8.422262187953368
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 136.75
# Episode: 4100
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 18.70258476933331
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 148.3
# Episode: 4200
# action choosen: 5
# next_state: (5, 14)
# q_value updated: 8.23802100140585
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 140.46
# Episode: 4300
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 18.63981725796099
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 143.94
# Episode: 4400
# action choosen: 2
# next_state: (2, 3)
# q_value updated: 12.828070087932815
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode:
# action choosen: 5
# next_state: (5, 11)
# q_value updated: 24.739554669101572
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 178.74
# Episode: 196300
# action choosen: 2
# next_state: (2, 6)
# q_value updated: 24.488444434389926
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.52
# Episode: 196400
# action choosen: 5
# next_state: (5, 7)
# q_value updated: 28.177653895638123
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 177.98
# Episode: 196500
# action choosen: 2
# next_state: (2, 14)
# q_value updated: 23.153309760387394
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 170.8
# Episode: 196600
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 26.364403111620586
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 175.95
# Episode: 196700
# action choosen: 2
# next_state: (2, 2)
# q_value updated: 25.061229151915818
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 178.8
# Episode: 196800
# action choosen: 2
# next_state: (2, 11)
# q_value updated: 31.221142119013884
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 175.99
# Episode: 196900
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 27.477879026262123
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 170.76
# Episode: 197000
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 32.005430765787665
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 172.67
# Episode: 197100
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 31.5695711291777
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 170.76
# Episode: 197200
# action choosen: 2
# next_state: (2, 13)
# q_value updated: 26.719517251326536
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 175.95
# Episode: 197300
# action choosen: 2
# next_state: (2, 12)
# q_value updated: 24.622893583822528
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 167.39
# Episode: 197400
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 24.901631714376265
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 172.04
# Episode: 197500
# action choosen: 3
# next_state: (3, 14)
# q_value updated: 22.315821802104153
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 169.76
# Episode: 197600
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 30.56752405077718
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.09
# Episode: 197700
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 27.846464888870322
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 167.96
# Episode: 197800
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 23.19242994397646
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.49
# Episode: 197900
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 26.232281619534582
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 166.81
# Episode: 198000
# action choosen: 5
# next_state: (5, 6)
# q_value updated: 28.40764431662126
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 167.5
# Episode: 198100
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 27.709286350490896
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 170.82
# Episode: 198200
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 28.993073563413837
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 172.15
# Episode: 198300
# action choosen: 5
# next_state: (5, 11)
# q_value updated: 24.772167384682117
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 186.49
# Episode: 198400
# action choosen: 2
# next_state: (2, 2)
# q_value updated: 29.688862273990082
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 166.8
# Episode: 198500
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 28.035122521201135
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 169.46
# Episode: 198600
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 24.11815681224351
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 175.33
# Episode: 198700
# action choosen: 2
# next_state: (2, 3)
# q_value updated: 24.99112253090949
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 174.13
# Episode: 198800
# action choosen: 2
# next_state: (2, 6)
# q_value updated: 28.657238436055774
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 175.59
# Episode: 198900
# action choosen: 2
# next_state: (2, 10)
# q_value updated: 28.33568876431331
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.69
# Episode: 199000
# action choosen: 2
# next_state: (2, 8)
# q_value updated: 26.01605223697529
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 169.74
# Episode: 199100
# action choosen: 2
# next_state: (2, 3)
# q_value updated: 22.718804330818962
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 188.38
# Episode: 199200
# action choosen: 5
# next_state: (5, 4)
# q_value updated: 24.246012716626726
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 169.07
# Episode: 199300
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 29.646240656146645
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.4
# Episode: 199400
# action choosen: 5
# next_state: (5, 8)
# q_value updated: 24.89251649072163
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 165.63
# Episode: 199500
# action choosen: 2
# next_state: (2, 14)
# q_value updated: 26.38014140991414
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 169.36
# Episode: 199600
# action choosen: 5
# next_state: (5, 3)
# q_value updated: 28.679022180169998
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 172.35
# Episode: 199700
# action choosen: 1
# next_state: (1, 8)
# q_value updated: 22.172400093679737
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 167.44
# Episode: 199800
# action choosen: 4
# next_state: (4, 8)
# q_value updated: 15.873838534055908
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 168.47
# Episode: 199900
# action choosen: 5
# next_state: (5, 10)
# q_value updated: 29.69128528939542
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 170.39

# %% [markdown]
# ## Q-Learning performance evaluation

# %%
avg_reward_ae = policy_eval(env=env_ae)
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 15.0
# Average rewards per episode: 179.6

# %% [markdown]
# ## Q_table visualization

# %%
save_q_table(env_ae,table_name='q_table_ae', dir_name=directory_name)

# %%
#header = ["name", "avg_reward_aa", "avg_reward_ae"]
data = [directory_name, avg_reward_aa, avg_reward_ae]
with open('trials/summary.csv', mode='a', newline='') as file:
    writer = csv.writer(file)
    #writer.writerow(header)
    writer.writerow(data)
